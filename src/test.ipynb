# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import random
import csv
import json
import os
import sys

# %%
with open('../Data/train.csv', 'r') as f:
    reader = csv.reader(f)
    train_data = list(reader)[1:]
  
train_data
# Out:
# [['CNC[C@H](c1ccc(Cl)c(Cl)c1)[C@@H](O)c1cccc(N)c1', '0'],
#  ['C[C@@H]1Cn2ncc(C3CCN(S(C)(=O)=O)CC3)c2CN1c1ccnc2[nH]ccc12', '0'],
#  ['CNC(=O)c1c(NCC2CCC3(CCCC3)CC2)nc(C#N)nc1OCC1CCN(C)CC1', '1'],
#  ['Cc1cc(CNc2nc(N)nc3ccn(Cc4ccccn4)c23)no1', '1'],
#  ['C[C@@]1(c2cc(CNCCC(F)(F)F)c(F)cc2F)CCSC(N)=N1', '1'],
#  ['NC(c1ccccc1)C(O)(c1cccnc1)c1cccnc1', '0'],
#  ['CCCS(=O)(=O)N1CC(CC#N)(n2cc(-c3ccnc4[nH]ccc34)cn2)C1', '0'],
#  ['C[C@@H]1COCCN1c1cc(C2(S(C)(=O)=O)CC2)nc(-c2cccc3[nH]ccc23)n1', '0'],
#  ['CN1CCC(COCc2cc(Cl)cc(C(F)(F)F)n2)(c2ccccc2)CC1', '1'],
#  ['COC1COCCC1N[C@@H]1C[C@H]2C[C@H](F)C[C@@]2(C(=O)N2CCc3ncc(C(F)(F)F)cc3C2)C1',
#   '0'],
#  ['Cc1nccn1Cc1cn(-c2ccc(Cl)cc2Cl)nn1', '1'],
#  ['CNC(=O)C(c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)c(F)cc1Cl)c1nccnc1C', '0'],
#  ['CCC(CN)=C1CN(c2nc(Oc3cnc(CO)nc3)nc3[nH]c4c(NC)cc(F)cc4c23)C1', '0'],
#  ['Cc1ccc(NC(=O)c2cc(C(F)(F)F)cnn2)cc1-c1ccc2c(c1)OC1(CCOCC1)CC(=O)N2', '1'],
#  ['C[C@@H]1CN(C(=O)OC2(C(F)(F)F)COC2)CCN1c1ncc(OCc2ccc(S(C)(=O)=O)cc2F)cn1',
#   '1'],
#  ['NC1(C(=O)NC(CCCN2CCOCC2)c2ccc(Cl)cc2)CCN(c2ncnc3[nH]ccc23)CC1', '0'],
#  ['CC(C)c1nccn1Cc1cn(-c2cccc(OC(F)(F)F)c2)nn1', '1'],
#  ['CC[C@@H](NC(=O)c1ccc(C#N)cc1)[C@H]1[C@@H]2C[C@@H](n3cnc4cc(F)c(F)cc43)C[C@@H]21',
#   '1'],
#  ['Cc1nsc(-c2nnc3n2CCN(C(=O)c2cc(F)c(F)c(F)c2F)[C@@H]3C)n1', '0'],
#  ['CCOC(=O)C1(c2ccccc2)CCN(C)CC1', '0'],
#  ['CN1CC[C@H](N(C)C(=O)N2CC(c3cc(F)ccc3F)=C[C@@]2(CO)c2ccccc2)[C@H](F)C1',
#   '1'],
#  ['CNC[C@H](c1ccc2ccccc2c1)[C@H](OCC(=O)NC)c1ccccc1', '0'],
#  ['CNC(C)c1ccccc1Oc1ccc(Cl)c(Cl)c1', '1'],
#  ['O=C(N[C@@H]1CN2CCC1CC2)c1cccc2oc(C3CC3)nc12', '1'],
#  ['CCN(CCCC(=O)NCCO)C(=O)c1ccc2c(c1)c1c(n2C)CC[C@@H](C2CCOCC2)C1', '0'],
#  ['O=C1COc2ccc(CNC34CCC(CCc5c(F)cnc6ccc(OCCCCO)nc56)(CC3)OC4)nc2N1', '1'],
#  ['C[C@@H]1Cc2c([nH]c3ccccc23)[C@@H](c2nccc(NCCNCCCF)c2F)N1CC(F)(F)F', '1'],
#  ['C[C@@H]1CNCCN1c1cc(=O)n(C)c(COc2ccccc2C(F)(F)F)n1', '0'],
#  ['CCc1[nH]nc(C(=O)Nc2ccc([C@H]3CNCCO3)cc2)c1C', '0'],
#  ['Cc1coc([C@H]2C[C@H]3CSC(N)=N[C@@]3(c3ccc(F)cc3F)CO2)n1', '1'],
#  ['CC(C)(CN)C(=O)N1CC(c2cc(F)ccc2F)=C[C@H]1c1ccccc1', '1'],
#  ['O=C1COc2ccc(CNC34CCC(CCc5c(F)cnc6ccc(N7CCOCC7)nc56)(CC3)OC4)nc2N1', '1'],
#  ['C[C@@H]1Cc2c(ccc3[nH]ncc23)[C@@H](c2ccc(NC3CN(CCCF)C3)c(F)c2)N1CC(F)(F)F',
#   '1'],
#  ['OC(c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1)c1nccn2cccc12', '1'],
#  ['CC(C)S(=O)(=O)N[C@H]1CN(C)C[C@@H]1c1ccc(-c2cccc(NS(C)(=O)=O)c2)cc1', '0'],
#  ['CS(=O)(=O)c1ccc(OCC[C@@H]2C[C@@H]2C2CCN(c3ncc(Cl)cn3)CC2)nc1', '1'],
#  ['COCCOCC#Cc1cc(-c2[nH]nc3c2Cc2cc(CN4CCN(C)CC4)ccc2-3)cs1', '1'],
#  ['COC(c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1)c1nccs1', '0'],
#  ['N#C[C@@H]1C[C@H](F)CN1C(=O)C[C@H](N)Cc1cc(F)c(F)cc1F', '0'],
#  ['CC(C)Oc1ccc(S(C)(=O)=O)cc1C(=O)N1CCN(c2ccc(C#N)cc2F)CC1', '1'],
#  ['COc1ccc(-c2ccc(C(=O)O)cc2C)cc1-c1cnc(N2CCCC2)nc1CN1C(=O)O[C@H](c2cc(C(F)(F)F)cc(C(F)(F)F)c2)[C@@H]1C',
#   '0'],
#  ['FC(F)c1cc(Cl)cc(-c2cnn(Cc3cc[nH]n3)c2)c1', '1'],
#  ['CO[C@@]12CC[C@@]3(C[C@@H]1[C@@](C)(O)C(C)(C)C)[C@H]1Cc4ccc(O)c5c4[C@@]3(CCN1CC1CC1)[C@H]2O5',
#   '1'],
#  ['CNC(C)c1ccc(Cl)cc1Oc1ccc(C)cc1', '1'],
#  ['C[C@@H]1Cc2c([nH]c3ccccc23)[C@@H](c2nccc(OCCNCCCF)c2F)N1CC1(F)COC1', '1'],
#  ['FC(F)(F)Oc1cccc(-c2ncccc2CC(c2cccnc2)c2cccnc2)c1', '1'],
#  ['N[C@H](C(=O)N1CC[C@H](F)C1)[C@H]1CC[C@H](NS(=O)(=O)c2ccc(F)cc2F)CC1', '0'],
#  ['O=C1COc2ccc(CNC34CCC(C[C@@]5(O)Cn6c(=O)ccc7ncc(F)c5c76)(CC3)OC4)nc2N1',
#   '0'],
#  ['Cc1c([C@@H]2CN3CCN(C(=O)Cc4ccc(-n5cnnn5)nc4)C[C@@H]3CO2)ccc2c1COC2=O', '0'],
#  ['CCN(CC(=O)NC1CC1)C(=O)c1ccc2c(c1)c1c(n2C)CCC(C2CCOCC2)C1', '0'],
#  ['CN(C)C(=O)[C@@H]1CCCN1Cc1ccc2c(c1)CC[C@H](N(C)C(=O)c1ccc(-c3ccc(F)cc3)cc1)C2',
#   '1'],
#  ['OC(c1ccc(OC2COC2)nn1)c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)c(F)cc1Cl', '0'],
#  ['CC(C)(C)[C@H](O)C(=O)N1CC(c2cc(F)ccc2F)=C[C@H]1c1cccc(O)c1', '1'],
#  ['Cc1cc(Cn2cc(-c3ccc(Cl)c(F)c3)cn2)n(C)n1', '1'],
#  ['Nc1nc(-c2ccc(F)cc2)cn1CC(O)c1ccc(C(F)(F)F)cc1Cl', '0'],
#  ['CC(C)(O)Cn1ncc(Nc2ncc3cc(Cl)c(C4CCN(C5COC5)CC4)cc3n2)c1Cl', '0'],
#  ['COC(=O)N(Cc1ccc2c(n1)NC(=O)CO2)C12CCC(CCc3c(F)cnc4ccc(OC)nc34)(CC1)OC2',
#   '1'],
#  ['CC(C)(C)C1CCC2(CC1)CCN(c1ccc(OC(F)(F)F)cc1)C(=O)N2Cc1ccc(C(=O)Nc2nnn[nH]2)cc1',
#   '1'],
#  ['CC(=O)N[C@@H](CCN1[C@@H]2CC[C@H]1C[C@@H](n1c(C)nc3c1CCN(C(C)=O)C3)C2)c1cccc(F)c1',
#   '1'],
#  ['COc1cccc2c1nc(N)n1nc(CN3CCN(c4cnc(C)s4)C[C@H]3C)nc21', '1'],
#  ['O=c1[nH]c(-c2ccc(C(F)(F)F)cc2)nc2c1CSCC2', '0'],
#  ['COc1ccc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2F)nn1', '0'],
#  ['CNC(=O)C(c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1)c1ncccc1Cl', '0'],
#  ['N#Cc1ccc(Cn2cncc2CN(CCCN)[C@H]2CCN(Cc3ccccc3)C2=O)cc1', '1'],
#  ['CC(C)(CCc1ccc(F)cc1)N1Cc2cc3c(cc2C1)OCO3', '1'],
#  ['O=C(NCCCN1CCCC1)c1cccn2c(=O)c3ccc4ccccc4c3nc12', '1'],
#  ['NC1=N[C@@]2(CO1)c1cc(-c3cccnc3F)ccc1Oc1cnc(C3=CCCOC3)cc12', '0'],
#  ['OC(c1cn2ccnc2cn1)c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)c(F)cc1F', '0'],
#  ['O=C(CNC(=O)c1cccc(C(F)(F)F)c1)NC1CN([C@H]2CC[C@@](O)(c3cncnc3)CC2)C1', '0'],
#  ['CCCN1C[C@H](CSC)C[C@@H]2c3cccc4[nH]cc(c34)C[C@H]21', '1'],
#  ['COc1ccc2ncc(C#N)c(CC(O)C34CCC(NCc5ccc6c(n5)NC(=O)CO6)(CC3)CO4)c2n1', '1'],
#  ['CCCN(c1cncnc1)P(=O)(c1ccccc1)c1ccccc1', '0'],
#  ['C=CC(=O)Nc1cc(Nc2nccc(-c3c[nH]c4ccccc34)n2)c(OC)cc1N1CCN(C)CC1', '1'],
#  ['O=c1ccc2ncc(F)c3c2n1C[C@@]3(O)CC12CCC(NCc3cc4c(cn3)OCS4)(CC1)CO2', '0'],
#  ['CN(C)Cc1ccc2c(c1)CC[C@H](N(C)C(=O)c1ccc(-c3ccc(F)cc3)cn1)C2', '1'],
#  ['O=S1(=O)CCNCC12CCN(c1nc(Oc3cccc(F)c3)cc(C(F)(F)F)n1)CC2', '1'],
#  ['CC(C)N(C)[C@@H]1CC[C@H](N2CC[C@H](NC(=O)c3cc(F)cc(C(F)(F)F)c3)C2=O)[C@H](CS(=O)(=O)c2ccccc2)C1',
#   '1'],
#  ['CC(C)(C)[C@H](NC(=O)OCCO)C(=O)N1CC(c2cc(F)ccc2F)=C[C@H]1c1ccccc1', '0'],
#  ['COc1ccc([C@@H](C)N[C@@H]2CC[C@@H](C(=O)N3CCC(c4ccccc4)(c4ccccc4)CC3)C(C)(C)C2)cc1',
#   '1'],
#  ['Cc1ccc2c(c1)CN([C@H](C)CCc1ccc(Cl)c(Cl)c1)C2', '1'],
#  ['C1=CCC(c2cc3ccccc3o2)CNC1', '1'],
#  ['COc1cc(C2CCN(C(C)=O)CC2)ccc1Nc1ncc(Cl)c(-c2cnc3ccccn23)n1', '1'],
#  ['FC(F)Oc1cc(-n2cc(Cn3ccnc3C3CC3)nn2)ccc1Cl', '1'],
#  ['COc1ccc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)cc1', '0'],
#  ['OC(c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1)c1c(F)cncc1Cl', '0'],
#  ['Cc1cccc(Oc2cc(C)nc(N3CCC4(CC3)CNCCO4)n2)c1', '1'],
#  ['CC(C(=O)N[C@]1(c2ccccc2)CC[C@@H](N2CCN(C(C)C)CC2)CC1)c1cc(C(F)(F)F)cc(C(F)(F)F)c1',
#   '1'],
#  ['Cn1ccnc1[C@]1(O)CC[C@H](N2CC(NC(=O)CNC(=O)c3cccc(C(F)(F)F)c3)C2)CC1', '1'],
#  ['Cc1ncc(-c2c(C)c(CNC3CCCC3)nn2-c2ncccc2Cl)cc1F', '0'],
#  ['Clc1ccc(-n2cc(Cn3ccnc3C3CC3)nn2)c(Cl)c1', '1'],
#  ['CN(C)c1ccc(/C=C/c2c(F)cccc2Cl)cn1', '0'],
#  ['O=S(=O)(Cc1cc(N2CCOCC2)nc(-c2ccccn2)n1)c1ccccc1', '0'],
#  ['O=c1ccc2ncc(F)c3c2n1C[C@@]3(O)CC12CCC(NC/C=C/c3c(F)cccc3F)(CC1)CO2', '1'],
#  ['CN1C[C@@H]2C[C@H]1CN2c1ncc(-c2ccccc2)cn1', '1'],
#  ['CC(C)S(=O)(=O)N[C@H]1CN(C)C[C@@H]1c1ccc(-c2cccs2)cc1', '0'],
#  ['Brc1cnc2nc(N3CCN4CCC3CC4)oc2c1', '1'],
#  ['CN(C)CCn1cc2c3c(cccc31)C1=C[C@@H](C(=O)N3CCCC3)CN(C(=O)Nc3ccccc3)[C@@H]1C2',
#   '0'],
#  ['COc1ccc2nccc(NC(=O)[C@H]3CC[C@H](NCc4ccc5c(c4)OCCO5)CC3)c2c1', '0'],
#  ['COc1ccc(CC(=O)NCc2ccccc2-c2ccccc2C(=O)NCCc2cccnc2)cc1', '1'],
#  ['O=C(C1CCN(c2cc(C(F)(F)F)ncn2)CC1)N1CC[C@H](N[C@H]2CC[C@@](O)(c3ccc(-c4ncccn4)cn3)CC2)C1',
#   '0'],
#  ['CC[C@@H](NC(=O)c1ccc(Cl)cc1)[C@H]1[C@@H]2C[C@@H](n3cnc4cc(F)c(F)cc43)C[C@@H]21',
#   '1'],
#  ['CC(=O)N[C@@H](CCN1[C@@H]2CC[C@H]1C[C@@H](n1c(C)nc3c1CCN(c1ccncn1)C3)C2)c1cccc(F)c1',
#   '1'],
#  ['CNC[C@H](c1ccc2ccccc2c1)[C@H](O)c1ccc(Cl)nc1', '1'],
#  ['COc1cc(Cl)nnc1C(O)c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)c(F)cc1Cl', '0'],
#  ['Cc1ccc(O)c([C@H](CCN(C(C)C)C(C)C)c2ccccc2)c1', '1'],
#  ['NC1(C(=O)NC(CS(N)(=O)=O)c2ccc(Cl)cc2)CCN(c2ncnc3[nH]ccc23)CC1', '0'],
#  ['N#Cc1cc(Oc2ccccc2)cc(N2CCC3(CC2)CNCCO3)c1', '1'],
#  ['COc1cc2c(cc1F)ncc(=O)n2C[C@H](N)[C@H]1CC[C@H](NCc2ncc3c(n2)NC(=O)CO3)CC1',
#   '0'],
#  ['NC1=N[C@@]2(c3cc(NC(=O)c4ccc(OC(F)F)cn4)ccc3F)COCC[C@H]2CS1', '1'],
#  ['CCN(CC)CCSc1nc(-c2cc(OC)c(C#N)cc2Cl)c2c(C#N)c[nH]c2n1', '1'],
#  ['CNCc1ccc(Cl)cc1Oc1ccc(C)c(C)c1', '1'],
#  ['C[C@H]1OC(=O)[C@]2(NCC(N)=O)CC(F)(F)[C@@H](C)[C@H](/C=C/c3ccc(-c4ccccc4C#N)cn3)[C@H]12',
#   '0'],
#  ['Cn1c(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)cccc1=O', '0'],
#  ['CC(C)Oc1cc(Nc2nc(N[C@@H](C)c3ccc(F)cn3)ncc2Cl)[nH]n1', '1'],
#  ['Fc1cccc(Oc2cc(C(F)(F)F)nc(N3CCC4(CNCCC45OCCO5)C3)n2)c1', '1'],
#  ['CC(C)c1nccn1Cc1cn(-c2ccc(Cl)c(Cl)c2)nn1', '1'],
#  ['COc1cc2c(cc1OC)CN([C@H](C)CCc1ccc(Cl)c(Cl)c1)C2', '1'],
#  ['NC(=O)C(c1cccnc1)c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1', '0'],
#  ['Cc1nccn1Cc1cn(-c2ccc(F)c(Cl)c2)nn1', '1'],
#  ['Cn1nccc1C(O)c1ccc(F)c(-c2nc(Cl)nc3cc(N4CCOCC4)ccc23)c1', '0'],
#  ['CC(C)(C)n1ncc2c1C(=O)CC1(CCN(C(=O)c3ccc4[nH]ncc4c3)CC1)C2', '1'],
#  ['CN1C[C@H](C(=O)Nc2ccc(Cl)cc2)[C@@H](c2ccc(/C=C/C(=O)Nc3ccccc3N)cc2F)C1',
#   '1'],
#  ['C[C@@H]1Cc2c(ccc3[nH]ncc23)[C@@H](c2ccc(NC3CN(CCCF)C3)cc2)N1CC(F)(F)F',
#   '1'],
#  ['CN1CCN(c2ccc3nc(Nc4ccc(Br)cn4)[nH]c3c2)CC1', '1'],
#  ['COc1cccc2c1nc(N)n1nc(CN3CCN(c4cnn(C(C)(C)C)c4)C[C@H]3C)nc21', '0'],
#  ['NC(=O)C(c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)c(F)cc1Cl)c1ncnn2cccc12', '1'],
#  ['Cc1nc2ccccc2n1C1CC2CCC(C1)N2CCC1(c2ccccc2)CCN(C(=O)c2cccc(C(=O)NO)c2)CC1',
#   '0'],
#  ['OC(c1cnc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1)c1nccs1', '0'],
#  ['CNC[C@H](c1ccc(Cl)c(Cl)c1)[C@@H](O)c1ccccc1SC', '1'],
#  ['CC(C)[C@H](CC(=O)[C@H]1Cc2ccc(O)cc2CN1)CN1CC[C@@](C)(c2ccccc2)[C@@H](C)C1',
#   '1'],
#  ['Cc1[nH]nc2c1c(=O)n(C[C@H](F)CN)c1cc(C3CCCCC3)c(C3CCCCC3)cc21', '1'],
#  ['CNc1cc(F)cc2c1[nH]c1nc(Oc3cnc(C)nc3)nc(N3CC(=C(F)CN)C3)c12', '0'],
#  ['c1ccc(CCNCCN(c2ccccc2)c2ccccc2)cc1', '1'],
#  ['CCC(NC(=O)c1ccc(Cl)cc1)[C@H]1[C@@H]2C[C@@H](n3cnc4ccccc43)C[C@@H]21', '1'],
#  ['CNC(=O)[C@@]12C[C@@H]1[C@@H](n1cnc3c(NC)nc(C#Cc4cccs4)nc31)[C@H](O)[C@@H]2O',
#   '1'],
#  ['NC1=N[C@@]2(CO1)c1cc(-c3cccnc3F)ccc1Oc1c2cc(C2=CCOCC2)nc1F', '0'],
#  ['C[C@H](O)C(=O)NC1CC(C)(C)Oc2nc(-c3ccc(Cl)cc3Cl)c(-c3ccc(Cl)cc3)cc21', '1'],
#  ['NC1=NC2(CO1)c1cc(NC(=O)c3ccc(Cl)cn3)ccc1OCC21CC1', '1'],
#  ['Clc1ccc(-n2cc(Cn3ccnc3C3CC3)nn2)cc1', '1'],
#  ['COc1cnc2ccc(=O)n(CCN3CCC(C4C(=O)Nc5ccc(Cl)cc54)CC3)c2c1', '1'],
#  ['C[C@H](O)CONC(=O)c1ncc2cncn2c1Nc1ccc(I)cc1F', '1'],
#  ['O=C1NC(=O)/C(=C\\c2ccccc2OCc2nnc(-c3ccccc3)o2)S1', '0'],
#  ['C[C@H]1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23', '0'],
#  ['COC1COCCC1N[C@@H]1C[C@H]2C[C@H](OC)C[C@@]2(C(=O)N2CCc3ncc(C(F)(F)F)cc3C2)C1',
#   '0'],
#  ['O=C(N[C@@H]1CN2CCC1CC2)c1cccc2oc(N3CCOCC3)nc12', '1'],
#  ['Cn1c(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)nccc1=O', '0'],
#  ['CC(C)(C)NC(=O)n1nc(NCC(=O)NC2CN([C@H]3CC[C@@H](c4ccc5c(c4)OCO5)CC3)C2)c2cc(C(F)(F)F)ccc21',
#   '1'],
#  ['OC(c1cccnc1)(c1cccnc1)C(c1ccccc1)N1CCCC1', '1'],
#  ['CCc1cccc2c(-c3nc(CN4CCCC4)cs3)cn(CC3CCOCC3)c12', '1'],
#  ['Cc1cccnc1-n1cc(CN2CCC3(CC2)OCc2ccccc23)c(C)n1', '1'],
#  ['CC(C(=O)N[C@]1(c2ccccc2)CC[C@@H](N2CCC3(CCOC3)CC2)CC1)c1cc(C(F)(F)F)cc(C(F)(F)F)c1',
#   '1'],
#  ['CCCNC(=O)CO[C@H](c1ccccc1)[C@H](CNC)c1ccc2ccccc2c1', '1'],
#  ['Clc1cc2sc(N3CCC(N4CCCCC4)CC3)nc2cn1', '1'],
#  ['CNc1ncc(/C=C2\\C[C@H]3[C@@H]4CC[C@H]5N(C)C(=O)C=C[C@]5(C)[C@H]4CC[C@]3(C)[C@H]2O)cn1',
#   '0'],
#  ['CCC[C@@H]1C[C@H](N(C)C(C)C)CC[C@@H]1N1CC[C@H](NC(=O)c2cc(C(F)(F)F)ccc2NC(=O)NCC)C1=O',
#   '1'],
#  ['N#CC1(NC(=O)[C@@H]2CCCC[C@H]2C(=O)N2CCN(c3nc(C4CC4)cs3)CC2)CC1', '0'],
#  ['CC(C)(C)COc1ccc2c(c1)[C@]1(COC(N)=N1)c1cc(-c3ccccn3)ccc1O2', '1'],
#  ['CC(C)[C@@H](CN1CC[C@@](C)(c2cccc(O)c2)[C@@H](C)C1)NC(=O)[C@H]1Cc2ccc(O)cc2CN1',
#   '1'],
#  ['CC(C)c1noc(N2CCN(c3ncc(OCc4ccc(CS(C)(=O)=O)cc4F)cn3)[C@H](C)C2)n1', '0'],
#  ['CC(C)c1nccn1Cc1cn(-c2ccc(F)c(C(F)F)c2)nn1', '1'],
#  ['CCc1c(C(=O)NC(C)(C)c2nnnn2C)nn(-c2ccc(Cl)cc2Cl)c1-c1ccc(Br)cc1', '1'],
#  ['Cc1ccc(C(=O)NC2CCc3ccc(CCN4CCN(c5nsc6ccccc56)CC4)cc32)cc1', '1'],
#  ['NC1(COc2ccc3ncc(F)c(CCC45CCC(NCc6ccc7c(n6)NC(=O)CO7)(CC4)CO5)c3n2)CC1',
#   '1'],
#  ['CC(C)CN(CC(C)C)c1cc(C(F)(F)F)cc(COCC2(c3ccc(F)cc3)CCN(C)CC2)n1', '1'],
#  ['COCCN1Cc2c(nc(C)c(CN)c2-c2ccc(Cl)cc2Cl)C1=O', '0'],
#  ['COc1cccc2c1nc(N)n1nc(CN3CCN(c4ncc(C)s4)C[C@H]3C)nc21', '0'],
#  ['CC(C)(C)COc1cnc2c(c1)[C@]1(COC(N)=N1)c1cc(-c3cncnc3)ccc1O2', '0'],
#  ['O=C1COc2cc(F)c(CNC34CCC(C[C@]5(O)Cn6c(=O)ccc7ncc(F)c5c76)(CC3)OC4)nc2N1',
#   '0'],
#  ['CN1C[C@@H]2C[C@H]1CN2c1ccc(-c2ccc3[nH]ccc3c2)nn1', '1'],
#  ['CN(C)Cc1ccccc1Oc1ccc(Cl)c(Cl)c1', '1'],
#  ['COc1ccc(-c2ccc(C(=O)O)cc2C)cc1-c1cnc(N(C)C)nc1CN1C(=O)O[C@H](c2cc(Cl)cc(C(F)(F)F)c2)[C@@H]1C',
#   '1'],
#  ['Cc1ccccc1[C@@H]1CCN(C[C@@H]2CCc3cccnc3[C@@H](O)C2)C[C@H]1CO', '1'],
#  ['O=C(CN1CCN(CCO)CC1)Nc1ccc(-c2cccc3c(=O)cc(N4CCOCC4)oc23)c2sc3ccccc3c12',
#   '0'],
#  ['Fc1cccc(Oc2cccc(N3CCC4(CC3)CNCCO4)c2F)c1', '1'],
#  ['COc1ccc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)ccc2F)nn1', '0'],
#  ['CC[C@H]1OC(=O)[C@H](C)C(=O)[C@H](C)[C@@H](O[C@@H]2O[C@H](C)C[C@H](N(C)C)[C@H]2O)[C@](C)(O)C[C@@H](C)C(=O)[C@H](C)[C@H]2N(C3CN(Cc4c(O)cnc5ncccc45)C3)C(=O)O[C@]12C',
#   '0'],
#  ['C[C@@H]1NC(c2cccc(C#N)c2)=N[C@@]1(c1ccc(F)cc1)c1ccc(F)nc1', '1'],
#  ['CC(=O)Nc1ccc(-c2cc3sc(N4CCC(N5CCCCC5)CC4)nc3cn2)cn1', '1'],
#  ['COc1cc(Nc2ncc(C)s2)nc(N[C@@H](C)c2ncc(F)cn2)n1', '0'],
#  ['CN1C[C@@H]2C[C@H]1CN2c1cnc(-c2ccc3occc3c2)cn1', '1'],
#  ['Cc1cc(Oc2cccc(F)c2)nc(N2CCC3(CC2)CNCCO3)n1', '1'],
#  ['Cc1cccc(C)c1C(=O)N1CCC(N2CC[C@@H](N(Cc3ccccc3)C(=O)C3CC3)C2)CC1', '1'],
#  ['CC(C)N(C)[C@@H]1CC[C@H](N2CC[C@H](NC(=O)c3cccc(C(C)(C)C)c3)C2=O)[C@H](CS(=O)(=O)C(C)C)C1',
#   '0'],
#  ['CN(C)[C@@H]1CCC[C@H]1Nc1nc(Nc2ccc(S(C)(=O)=O)cc2)ncc1C(F)(F)F', '1'],
#  ['N#CC1(NC(=O)[C@@H]2CCCC[C@H]2C(=O)N2CCN(c3nc4ccccc4s3)CC2)CC1', '1'],
#  ['CC(C)N(C)[C@@H]1CC[C@H](N2CC[C@H](NC(=O)c3cc(C(F)(F)F)cc(C(F)(F)F)c3)C2=O)[C@H](CS(=O)(=O)c2ccccc2)C1',
#   '1'],
#  ['COCCNC(=O)c1nc2c(N3CCOCC3)nc(-c3cnc(N)nc3)cn2c1C', '0'],
#  ['CC(C)COc1cc(CCC(C)(C)N2Cc3cccc(F)c3C2)ccc1O', '1'],
#  ['COc1cc(OC2CCNCC2)ccc1Nc1ncc(Cl)c(-c2cnc3ccccn23)n1', '1'],
#  ['CC(C)CCOc1ccc2ncc(F)c(CCC34CCC(NCc5ccc6c(n5)NC(=O)CO6)(CC3)CO4)c2n1', '1'],
#  ['COc1ccc(OCCNCCCF)cc1[C@@H]1c2[nH]c3ccccc3c2C[C@@H](C)N1CC(F)F', '1'],
#  ['Cc1cc(Cn2cc(-c3ccc(Cl)c(C(F)F)c3)cn2)n(C)n1', '1'],
#  ['Cc1c(CNC2CCCC2)nn(-c2ncccc2Cl)c1-c1ccc(Cl)nc1', '1'],
#  ['Cc1nccnc1C(O)c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)c(F)cc1F', '0'],
#  ['C[C@@H]1Cc2c([nH]c3ccccc23)[C@@H](c2c(F)ccc(OCCNCCCF)c2F)N1CC(F)(F)CO',
#   '1'],
#  ['FC(F)(F)c1cc(Oc2ccccc2)nc(N2CCC3(CC2)CNCCO3)n1', '1'],
#  ['CC(C)Oc1ccc(CC[C@@H](C)N2Cc3cccc(F)c3C2)cc1OC(C)C', '1'],
#  ['CN(CCCN)C(=O)N1CC(c2cc(F)ccc2F)=C[C@H]1c1ccccc1', '1'],
#  ['COc1ncccc1C(=O)N1CC[C@H](NCc2cncn2Cc2ccc(C#N)cc2)C1=O', '1'],
#  ['Cn1nccc1Cn1cc(-c2ccc(F)c(C(F)F)c2)cn1', '1'],
#  ['C[C@H](CCc1ccc(Cl)c(Cl)c1)N1Cc2cccc(F)c2C1', '1'],
#  ['COC1CCC2(CC1)Cc1ccc(C#N)cc1C21N=C(N)N(CC2CCCO2)C1=O', '1'],
#  ['C[C@@H]1Cc2c([nH]c3ccccc23)[C@@H](c2c(F)ccc(NCCNCCCF)c2F)N1CC(F)(F)F', '1'],
#  ['CCC(NC(=O)c1ccc(Cl)cc1)[C@H]1[C@@H]2C[C@@H](n3cnc4c(F)cccc43)C[C@@H]21',
#   '1'],
#  ['O=C1CCCN1c1nccnc1C(O)c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1', '0'],
#  ['COc1ccc2ncc(F)c(CCC34CCC(NCc5nc6c(c(C)c5C(C)C)OCC(=O)N6)(CC3)CO4)c2n1',
#   '1'],
#  ['Nc1nc2cc3c(cc2s1)CCN(Cc1ncon1)CC3', '0'],
#  ['O=c1ccc(-c2nnc(C3CCN(Cc4ccc(-c5nc6nc(N7CCN(CCO)CC7)ncc6cc5-c5ccccc5)cc4)CC3)[nH]2)c[nH]1',
#   '1'],
#  ['Cc1cc2[nH]c(C3CCN(CCn4c(=O)ccc5ncc(F)cc54)CC3)nc2cc1Cl', '1'],
#  ['CCn1cc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)cn1', '0'],
#  ['CNC[C@H](c1ccc2ccccc2c1)[C@H](OC)c1ccc2c(c1)OCO2', '1'],
#  ['O=C(CNC(=O)c1cccc(C(F)(F)F)c1)NC1CN([C@H]2CC[C@@](O)(c3ccns3)CC2)C1', '0'],
#  ['C[C@@H]1Cc2c(ccc3[nH]ncc23)[C@@H](c2ccc(NC3CN(CCCF)C3)nc2)N1CC1(F)CC1',
#   '1'],
#  ['COc1cccc(C(=O)N2CCn3c(-c4nc(C)ns4)nnc3[C@H]2C)c1', '0'],
#  ['CC1(C)CC(NC(=O)C(F)(F)CO)c2cc(-c3ccc(Cl)cc3)c(-c3ccc(Cl)cc3Cl)nc2O1', '1'],
#  ['Nc1cccnc1[C@H]1CC[C@H](N2CC(NC(=O)CNC(=O)c3cccc(C(F)(F)F)c3)C2)CC1', '0'],
#  ['CC(C)=CCn1c(N2CCC[C@H](N)C2)c(C#N)c2c1c(=O)n(Cc1nc(C)c3ccccc3n1)c(=O)n2C',
#   '1'],
#  ['CCOc1cc(Nc2nc3c(cc2F)ncn3[C@@H](CO)c2ccc(F)cn2)[nH]n1', '0'],
#  ['COc1ncc(-c2ccc(C(=O)O)cc2C)cc1-c1cc(C(F)(F)F)c(OC)nc1CN1C(=O)O[C@H](c2cc(C(F)(F)F)cc(C(F)(F)F)c2)[C@@H]1C',
#   '0'],
#  ['C1=CCC(c2ccc3ccccc3c2)CNC1', '1'],
#  ['COc1ccc(C(=O)N2CCOCC2)cc1Nc1ncc(Cl)c(-c2cnc3ccccn23)n1', '1'],
#  ['COC1COCCC1N[C@@H]1C[C@H]2OCC[C@@]2(C(=O)N2CCc3ncc(C(F)(F)F)cc3C2)C1', '0'],
#  ['CO[C@@H]1OC2(CCN(Cc3ccccc3)CC2)c2cnn(-c3ccccc3)c21', '1'],
#  ['Cc1nccnc1C(O)c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)ccc1Cl', '0'],
#  ['CCc1nsc(-c2nnc3n2CCN(C(=O)c2ccc(F)cc2)[C@@H]3C)n1', '0'],
#  ['COC1CN(c2nnc(C)c3c(C)n(-c4ccc(Cl)cc4OC(F)(F)F)nc23)C1', '1'],
#  ['COc1cc(NC2CN(CCCF)C2)ccc1[C@@H]1c2ccc3[nH]ncc3c2C[C@@H](C)N1CC(F)F', '1'],
#  ['CC(=O)Nc1ccc2cnn(-c3cc(NC4CC4)n4ncc(C#N)c4n3)c2c1', '0'],
#  ['CC(C)(C)CNc1nc(C#N)nc(N2CCOCC2)c1N', '0'],
#  ['CS(=O)(=O)c1ccc(-c2cnc3ccc(-c4cccc(S(=O)(=O)CCCN)c4)nn23)cc1', '0'],
#  ['Cc1cn[nH]c1C(=O)N[C@@H]1CC(C)(C)Oc2nc(-c3ccc(Cl)cc3Cl)c(-c3ccc(Cl)cc3)cc21',
#   '1'],
#  ['COC1COCCC1N[C@@H]1C[C@H]2CCC[C@@]2(C(=O)N2CCc3ccc(Cl)cc3C2)C1', '0'],
#  ['C[C@@]1(c2cc(NC(=O)c3ccc(OC(F)F)cn3)ccc2F)Cn2nc(C#N)cc2C(N)=N1', '1'],
#  ['N[C@]1(c2ccccc2)CC[C@H](N2CC(NC(=O)CNC(=O)c3cccc(C(F)(F)F)c3)C2)CC1', '1'],
#  ['Cn1cnc2c(C(O)c3cc(-c4ncnc5cc(N6CCOCC6)ccc45)ccc3Cl)ncnc21', '0'],
#  ['Cc1oc(-c2ccccc2)nc1CCOc1cccc(C[C@@H]2C(=O)N(c3ccc(C(C)(C)C)cc3)[C@@H]2C(=O)O)c1',
#   '1'],
#  ['Cn1ccc(Cn2cc(-c3cccc(OC(F)(F)F)c3)cn2)n1', '1'],
#  ['O[C@H]1C[C@H](CN2CC[C@H](c3ccc(F)cc3Cl)[C@@H](O)C2)Cc2cccnc21', '0'],
#  ['Cc1cnc2c(-c3ccc(C(=O)N(c4ncccc4C)[C@@H]4CCCNC4)cc3F)cnn2c1', '1'],
#  ['CC(C)c1noc(-c2nnc3n2CCN(C(=O)c2ccc(F)cc2)[C@@H]3C)n1', '1'],
#  ['CNC(=O)c1c(NCC2CCC3(CCC3)CC2)nc(C#N)nc1OCC1CCN(C(C)C)CC1', '1'],
#  ['Cc1nc(Nc2ncc(C(=O)Nc3c(C)cccc3Cl)s2)cc(N2CCN(CCO)CC2)n1', '0'],
#  ['CC#Cc1cncc(-c2cccc(C3(C4CC4)N=C(C)C(N)=N3)c2)c1', '1'],
#  ['COc1cccc2c1nc(N)n1nc(CN3CCN(c4ccc(F)cn4)C[C@H]3C)nc21', '1'],
#  ['C[C@@H]1CN(c2nnc(C(F)(F)F)o2)CCN1c1ncc(OCc2ccc(CS(C)(=O)=O)cc2F)cn1', '0'],
#  ['NC1=N[C@]2(CO1)c1cc(C3=CCOCC3)ccc1Oc1ccc(-c3cncnc3)cc12', '0'],
#  ['Cc1nccnc1C(O)c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)sc23)c1', '0'],
#  ['CCO[C@H]1CC[C@@H](N2CC(NC(=O)CNc3n[nH]c4ccc(C(F)(F)F)cc34)C2)CC1', '1'],
#  ['CC(Oc1ccc(S(C)(=O)=O)cc1C(=O)N1CCN(c2ncc(C(F)(F)F)cn2)CC1)C(F)(F)F', '0'],
#  ['Cc1cc(C)n(-c2cc(NC(=O)COc3cccc(CN(C)C)c3)nc(-c3ccc(C)o3)n2)n1', '1'],
#  ['C[C@H]1C[C@H]2CSC(N)=N[C@@]2(c2cc(NC(=O)c3ccc(OC(F)F)cn3)ccc2F)CO1', '1'],
#  ['CN1CCC(COCc2cc(C(F)(F)F)cc(N3CCC(C#N)C3)n2)(c2ccc(F)cc2)CC1', '1'],
#  ['COc1cnc(C(=O)Nc2ccc(F)c([C@]3(C)CS(=O)(=O)[C@](C)(CF)C(=N)N3)c2)cn1', '0'],
#  ['CCc1nccn1Cc1cn(-c2ccc(Cl)c(C(F)F)c2)nn1', '1'],
#  ['Cc1ccc(-c2ccc(N3CC(CNC(=O)c4ccc(-c5nc6cc(C#N)cc(C(C)C)c6o5)cc4)OC3=O)nc2)s1',
#   '1'],
#  ['CCC(NCCCC[C@@H](C[C@@H](OC)c1ccc(F)cc1)C(=O)NO)c1ccc(F)cc1', '1'],
#  ['Cc1ccccc1C1CCN(C[C@@H]2Cc3cccnc3[C@@H](O)C2)CC1', '0'],
#  ['Cc1nsc(-c2nnc3n2CCN(C(=O)c2cc(F)cc(F)c2)[C@@H]3C)n1', '0'],
#  ['COc1cnc2ccc(=O)n(CCN3CCC(c4nc5cc(Cl)ccc5[nH]4)CC3)c2c1', '1'],
#  ['CCCC(CCC)c1nc2c(Nc3ccc(I)cc3)nc3ccccc3c2[nH]1', '0'],
#  ['Cc1cncnc1C(O)c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)ccc1F', '0'],
#  ['Cc1nc2ccccc2n1C1CC2CCC(C1)N2CCC1(c2ccccc2)CCN(C(=O)c2ccc(S(N)(=O)=O)cc2)CC1',
#   '0'],
#  ['OC(c1cccnc1-c1cccc(Cl)c1)C(c1cccnc1)c1cccnc1', '0'],
#  ['CN1C[C@@H]2C[C@H]1CN2c1cnc(-c2ccccc2)cn1', '1'],
#  ['CN1C(=O)C=C[C@]2(C)[C@H]3CC[C@]4(C)[C@@H](O)/C(=C/c5cc(F)cc(F)c5)C[C@H]4[C@@H]3CC[C@@H]12',
#   '1'],
#  ['Cn1cc(Br)c(C(=O)N2CCN(CC(=O)c3ccc(F)cc3)CC2)n1', '1'],
#  ['CCn1nc(Cc2ccccc2)cc1C1CCN(C[C@H]2CN([C@@H](C(=O)O)C(C)C)C[C@@H]2c2cccc(F)c2)CC1',
#   '0'],
#  ['Cc1cc(C(=O)Nc2ccc([C@H]3CNCCO3)cc2)ccn1', '0'],
#  ['O=C(Nc1ccc([C@H]2CNCCO2)cc1)c1coc(-c2ccccc2)n1', '1'],
#  ['COc1ccc(-c2ccc(C(=O)O)cc2C)cc1-c1cnc(N(C)C)nc1CN1C(=O)O[C@H](c2cc(Cl)cc(Cl)c2)[C@@H]1C',
#   '1'],
#  ['CC(C)(C)C#Cc1cnc2c(c1)[C@]1(COC(N)=N1)c1cc(-c3cccnc3F)ccc1O2', '1'],
#  ['OC(c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)sc23)c1)c1nccs1', '0'],
#  ['OC(c1cccnc1)(c1cccnc1)C(c1ccccc1)N1CCCCC1', '1'],
#  ['CNC(=O)c1ccc(Nc2ncc(F)c(-c3cnc(C)n3C(C)C)n2)cc1F', '1'],
#  ['Cn1c(C(O)c2ccc(F)c(-c3ncnc4cc(N5CCOCC5)ccc34)c2)nccc1=O', '0'],
#  ['O=C1COc2cc(OC(=O)c3ccccc3)c(CNC34CCC(C[C@]5(O)Cn6c(=O)ccc7ncc(F)c5c76)(CC3)OC4)nc2N1',
#   '0'],
#  ['Cc1n[nH]c(C)c1Cn1cc(-c2ccc(F)c(C(F)F)c2)cn1', '1'],
#  ['Cc1ccc(C(=O)Nc2ccc3c(c2)C(F)(F)C[C@@H]3N2CCN(C)CC2)cc1C#Cc1cnc2cccnn12',
#   '1'],
#  ['COc1ccc2ncc(F)c(C[C@H](O)[C@H]3OC[C@H](NC(=O)c4ccc5c(n4)NC(=O)CO5)CO3)c2n1',
#   '0'],
#  ['N#Cc1ccc(C(=O)Nc2csc([C@]34COCC[C@H]3CSC(N)=N4)c2)nc1', '1'],
#  ['CN(C)c1cnc2c(CCC34CCC(NCc5ccc6c(n5)NC(=O)CO6)(CC3)CO4)c(F)cnc2c1', '1'],
#  ['OCC1CC2(c3ccccc3)NC1CCC2NCc1cc(OC(F)(F)F)ccc1OC1CC1', '1'],
#  ['O=C1COc2ccc(CN[C@@H]3CCN(CCn4c(=O)ccc5ncc(Oc6ccon6)cc54)C[C@@H]3F)nc2N1',
#   '0'],
#  ['OCc1nccn1Cc1cn(-c2ccc(Cl)cc2)nn1', '1'],
#  ['COC1COCCC1N[C@@H]1C[C@H]2C[C@H](O)C[C@@]2(C(=O)N2CCc3ncc(C(F)(F)F)cc3C2)C1',
#   '0'],
#  ['CNC(C)c1cc(C(F)(F)F)ccc1Oc1ccc(Cl)c(Cl)c1', '1'],
#  ['Cc1nccnc1C(O)c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)c(F)cc23)c1', '0'],
#  ['CC#CCn1c(N2CCC[C@H](N)C2)c(C#N)c2c1c(=O)n(Cc1nccc3ccccc13)c(=O)n2C', '0'],
#  ['COCCN(C)Cc1csc(-c2cn(CC3CCOCC3)c3c(Cl)cccc23)n1', '1'],
#  ['N#Cc1cccc2c1C(=O)Nc1ncc(-c3ccccc3)cc1C2', '1'],
#  ['Cc1cc(Cn2cc(-c3cccc(OC(F)(F)F)c3)cn2)n(C)n1', '1'],
#  ['N#Cc1cccc(Oc2cc(C(F)(F)F)nc(N3CCC4(CC3)CNCCO4)n2)c1', '1'],
#  ['CO[C@@H]1COCC[C@@H]1N[C@@H]1CC[C@@](C(=O)N2CCN(c3nccc(C(F)(F)F)n3)CC2)(C(C)C)C1',
#   '1'],
#  ['CCN(CC)C(=O)[C@@H]1C=C2c3cccc4[nH]cc(c34)C[C@H]2N(C(=O)Nc2ccccc2)C1', '0'],
#  ['CN(CC(=O)NC1CC1)C(=O)c1ccc2c(c1)c1c(n2C)CC[C@H](C2CCOCC2)C1', '0'],
#  ['CC(C)COc1cc(CCC(C)(C)N2Cc3ccc(S(C)(=O)=O)cc3C2)ccc1O', '1'],
#  ['Cc1cc(Cl)cnc1C(=O)Nc1ccc2c(c1)C1(COC(N)=N1)C1(CC1)CO2', '1'],
#  ['N#CC1(NC(=O)[C@@H]2CCCC[C@H]2C(=O)N2CCN(c3nc4c(s3)COCC4)CC2)CC1', '0'],
#  ['CC1(C)C[C@@H](NC(=O)c2ccccc2O)c2cc(-c3ccc(Cl)cc3)c(-c3ccc(Cl)cc3Cl)nc2O1',
#   '0'],
#  ['CN1C[C@@H]2C[C@H]1CN2c1cnc(-c2ccc3sccc3c2)cn1', '1'],
#  ['CC(C)(C)CCc1ccc2c(c1)[C@]1(COC(N)=N1)c1cc(-c3cncnc3)ccc1O2', '1'],
#  ['C[C@H]1SC(N)=N[C@@]2(c3ccc(F)cc3F)CO[C@@H](c3cnn(C)c3)C[C@@H]12', '1'],
#  ['CC(CCc1ccc(Cl)c(Cl)c1)N1Cc2ccc3ccccc3c2C1', '0'],
#  ['CSc1nc(-c2cc(OCCN3CCCC3)c(Cl)cc2Cl)c2c(C#N)c[nH]c2n1', '1'],
#  ['O=C1C(c2cc(C(F)(F)F)cc(C(F)(F)F)c2)CCN1[C@]1(c2ccccc2)CC[C@@H](N2CCC3(CCOC3)CC2)CC1',
#   '1'],
#  ['NC1=N[C@@]2(CO1)c1cc(-c3cccnc3F)ccc1Oc1c2cc(C2=COCCC2)nc1F', '0'],
#  ['NC(=O)c1ccc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)nn1', '0'],
#  ['Cc1cccc(-c2ccc(/C=C/[C@@H]3[C@@H]4[C@@H](C)OC(=O)[C@]4(O)CC(F)(F)[C@H]3C)nc2)c1C#N',
#   '1'],
#  ['O=C1c2cccc3c2[C@H](CCC3)CN1[C@@H]1CN2CCC1CC2', '1'],
#  ['C[C@@H]1Cc2c([nH]c3ccc(F)cc23)[C@@H](c2c(F)cnc(OCCNCCCF)c2F)N1CC(F)(F)CO',
#   '1'],
#  ['CC(C(=O)NC1(c2ccccc2)CCC(N2CCC(O)(Cc3ccccc3)CC2)CC1)c1cc(C(F)(F)F)cc(C(F)(F)F)c1',
#   '1'],
#  ['Cc1c(OCCNCCCF)cncc1[C@@H]1c2[nH]c3ccccc3c2C[C@@H](C)N1CC(F)(F)F', '1'],
#  ['COc1cc(N2CCN(C(=O)N(C)C)CC2)ccc1Nc1ncc(Cl)c(-c2cnc3ccccn23)n1', '1'],
#  ['Cc1cnc(Nc2cc(N3CCOCC3)nc(N[C@@H](C)c3ccc(F)cn3)n2)s1', '1'],
#  ['CO[C@]1(CC23CCC(NCc4ccc5c(n4)NC(=O)CO5)(CC2)CO3)Cn2c(=O)ccc3ncc(F)c1c32',
#   '0'],
#  ['CC(C)S(=O)(=O)N[C@@H]1COC[C@@H]1c1ccc(-c2cccs2)cc1', '0'],
#  ['COCCC(NC(=O)C1(N)CCN(c2ncnc3[nH]ccc23)CC1)c1ccc(Cl)cc1', '1'],
#  ['CN(C)c1ncc(/C=C/c2c(F)cccc2F)cn1', '0'],
#  ['Cc1nn(-c2c(Cl)cccc2NS(C)(=O)=O)cc1CN1CCC2(CC1)OCc1ccccc12', '1'],
#  ['FC(F)c1cc(-c2cnn(Cc3cc[nH]n3)c2)ccc1Cl', '1'],
#  ['Cn1nccc1Cn1cc(-c2ccc(Cl)cc2)cn1', '1'],
#  ['C=CC(=O)Nc1cc(Nc2ncc(Cl)c(-c3cnn4ccccc34)n2)c(OC)cc1N(C)CCN(C)C', '1'],
#  ['CC(=O)Nc1cccc(-c2ccc([C@H]3CN(C)C[C@@H]3NS(=O)(=O)C(C)C)cc2)c1', '1'],
#  ['CCC1(CNCCC#N)CN(c2c(F)cc3c(=O)c(C(=O)O)cn(C4CC4)c3c2C)C1', '0'],
#  ['CC(C)(CCc1ccc(O)c(OC(F)(F)F)c1)N1Cc2ccc(S(C)(=O)=O)cc2C1', '1'],
#  ['COc1cnc(C(O)c2ccc(F)c(-c3ncnc4cc(N5CCOCC5)ccc34)c2)nc1', '0'],
#  ['NC1=NC2(c3cc(-c4cncnc4)ccc3OCC23CC3)c2cccc(F)c21', '1'],
#  ['CNC[C@H](c1ccc(Cl)c(Cl)c1)[C@H](O)c1cccc(N)c1', '0'],
#  ['CC(C)c1noc(C2CCN(C(C)C[C@H](NC(=O)C3CCC3)c3ccccc3)CC2)n1', '1'],
#  ['Cc1nc(Nc2nc3cnc(N4CCN(C)CC4)cc3[nH]2)cc(C2CC2)c1F', '1'],
#  ['CN1CC=CC[C@H](c2ccc(Cl)c(Cl)c2)C1', '1'],
#  ['Cc1nc(N2CCC(N3CCCC3)CC2)nc2ccc(NC(=O)COc3ccc(Cl)cc3)cc12', '1'],
#  ['Nc1nccn1Cc1cn(-c2ccc(Cl)c(C(F)F)c2)nn1', '1'],
#  ['CN1C[C@@H]2C[C@H]1CN2c1cnc(-c2ccc3cc[nH]c3c2)cn1', '1'],
#  ['CCC[C@@H]1C[C@H](N(C)C(C)C)CC[C@@H]1N1CC[C@H](Nc2ncnc3ccc(C(F)(F)F)cc23)C1=O',
#   '1'],
#  ['C[C@@H]1Cc2c([nH]c3ccccc23)[C@@H](c2cccc(OCCNCCCF)c2C(F)F)N1CC(F)(F)CO',
#   '1'],
#  ['Cc1ccc(COC(=O)N2CC[C@H](CNc3ncc4cn[nH]c4n3)C(F)(F)C2)cc1', '1'],
#  ['CC(C)c1ccc(S(=O)(=O)Cc2ccc([C@]34CNC[C@H]3C4)cc2)cc1', '1'],
#  ['Cc1cc(C#N)ccc1-c1ccnc(NCc2[nH]nc(-c3ccccc3)c2Cl)c1', '0'],
#  ['CNCc1cc(N2CCCS2(=O)=O)ccc1Oc1ccc(Cl)cc1C', '1'],
#  ['COc1cc(OC)c(F)c(COc2cnc(Nc3cnn(CCN4CCNCC4)c3)nc2)c1F', '0'],
#  ['CO[C@H]1CN(CCn2c(=O)ccc3ccc(C#N)cc32)CC[C@H]1NCc1cc2c(cn1)OCCO2', '0'],
#  ['COc1ccc(Cl)cc1-c1ccnc(Nc2ccc(N3CCOCC3)c(OC)c2)c1', '1'],
#  ['COc1cccc2c1nc(N)n1nc(CN3CCN(c4ncccn4)C[C@H]3C)nc21', '0'],
#  ['Cc1cc(Cl)nc(C)c1C(=O)NCC[C@@H](C)N1CCC(N(Cc2ccsc2)C(=O)CC#N)CC1', '1'],
#  ['CN(C)c1cccc([C@H]2CC[C@@H](N3CC(NC(=O)CNc4nn(C)c5ccc(C(F)(F)F)cc45)C3)CC2)c1',
#   '1'],
#  ['CC(C)c1cc(C#N)cc2nc(-c3ccc(C(=O)NC[C@H]4CC[C@H](c5ccc(Cl)cc5)CC4)cc3)oc12',
#   '0'],
#  ['CC1(C)CC(NC(=O)C(C)(O)C(F)(F)F)c2cc(-c3ccc(Cl)cc3)c(-c3ccc(Cl)cc3Cl)nc2O1',
#   '1'],
#  ['C[C@@H](Oc1ccc(S(C)(=O)=O)cc1C(=O)N1CCN(c2ncc(C(F)(F)F)cc2F)CC1)C(C)(C)C',
#   '0'],
#  ['Cc1nc(-c2nnc3n2CCN(C(=O)c2ccc(-c4ccccc4)cc2)[C@@H]3C)cs1', '0'],
#  ['NC1=N[C@@]2(CO1)c1cc(-c3cccnc3F)ccc1Oc1cnc(C3=CCOCC3)cc12', '0'],
#  ['NC(=O)C(c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1)c1c(F)cncc1F', '0'],
#  ['O=C1COc2ccc(CNC34CCC(C[C@]5(O)Cn6c(=O)c(F)cc7ncc(F)c5c76)(CC3)OC4)nc2N1',
#   '0'],
#  ['NCC(=O)NCC1(O)CCN(c2nc(Oc3cccc(F)c3)cc(C(F)(F)F)n2)CC1', '1'],
#  ['O=C1COc2ccc(CNC34CCC(C[C@@]5(O)CN6C(=O)CCc7ncc(F)c5c76)(CC3)OC4)nc2N1',
#   '0'],
#  ['C[C@@H]1Cc2c(ccc3[nH]nc(F)c23)[C@@H](c2cnc(NC3CN(CCCF)C3)cn2)N1CC(F)(F)F',
#   '1'],
#  ['Cc1nccn1Cc1cn(-c2ccc(Cl)c(OC(F)F)c2)nn1', '1'],
#  ['C=C(F)COc1ccc(Cl)cc1[C@H]1C[C@@H]1CN', '1'],
#  ['CC[C@H]1OC(=O)[C@H](C)[C@@H](O[C@H]2C[C@@](C)(OC)[C@@H](O)[C@H](C)O2)[C@H](C)[C@@H](O[C@H]2O[C@@H](C)C[C@@H](N(C)C)[C@@H]2O)[C@](C)(O)C[C@@H](C)C(=O)[C@H](C)[C@@H](O)[C@]1(C)O',
#   '0'],
#  ['Cn1cnc2ncnc(C(O)c3cc(-c4ncnc5cc(N6CCOCC6)ccc45)c(F)cc3F)c21', '0'],
#  ['NC1=N[C@@]2(CO1)c1cc(-c3cccnc3F)ccc1Oc1c2cc(N2CCOCC2)nc1F', '0'],
#  ['Cc1cc(CNc2nc(N)nc3ccn(Cc4ccc(F)cn4)c23)no1', '1'],
#  ['Cc1nc2ccccc2n1C1CC2CCC(C1)N2CCC1(c2cccc(F)c2)CCN(C(=O)C(C)(C)C(=O)O)CC1',
#   '0'],
#  ['Cc1ccc2oc(N3CCN4CCC3CC4)nc2n1', '0'],
#  ['Cc1ccc(N2CCN(Cc3cc(C(=O)N[C@H]4CCCC[C@@H]4O)c(=O)n4ccccc34)CC2)nc1', '1'],
#  ['C=CCN1C[C@H]2C[C@@]2(c2ccc(NS(=O)(=O)c3ccc(C(C)C)cc3)cc2)C1', '1'],
#  ['CC(C)c1nc(N2CCN(c3ncc(OCc4ccncc4C#N)cn3)[C@H](C)C2)no1', '1'],
#  ['C[C@H]1OC(=O)[C@]2(CC(N)=O)CC(F)(F)[C@@H](C)[C@H](/C=C/c3ccc(-c4cccc(F)c4)cn3)[C@H]12',
#   '1'],
#  ['O=C1COc2ccc(CNC34CCC(CCc5c(F)cnc6ccc(OCCCCCO)nc56)(CC3)OC4)nc2N1', '1'],
#  ['Cc1cc(=O)n(C[C@H](N)[C@H]2CC[C@H](NCc3ncc4c(n3)NC(=O)CO4)CC2)c2cc(F)ccc12',
#   '0'],
#  ['COc1ncc(Cl)nc1C(O)c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1', '1'],
#  ['Cc1cc(C#N)ccc1-c1ccnc(NCc2n[nH]c3ncccc23)c1', '1'],
#  ['COc1cc(C)ccc1-c1cnc2sc(N3CCC(O)(CN)CC3)nn12', '0'],
#  ['CCc1nn(CCOCC(F)(F)F)c2c(Nc3ccncn3)nc(N3CCN[C@H](C)C3)nc12', '1'],
#  ['N#Cc1ccc(Cn2cncc2CN(CCCc2ccccc2)[C@H]2CCN(Cc3ccccc3)C2=O)cc1', '1'],
#  ['CC(c1ccccc1Oc1ccc(Cl)c(Cl)c1)N(C)C', '1'],
#  ['CN(C)C(=O)c1cccc(-c2ccccc2CC(c2cccnc2)c2cccnc2)c1', '0'],
#  ['Nc1ccc(-c2nnc(C3CCN(Cc4ccc(-c5nc6cc[nH]c(=O)c6cc5-c5ccccc5)cc4)CC3)[nH]2)cn1',
#   '1'],
#  ['N[C@H](C(=O)N1CCC(F)(F)C1)C1CCCCC1', '0'],
#  ['CNC[C@@H](O)CCN1c2ccccc2N(c2ccccc2F)S1(=O)=O', '0'],
#  ['N#CCOc1ccc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)nn1', '0'],
#  ['N[C@H](C(=O)N1CCCC1)[C@H]1CC[C@H](NC(=O)c2ccc(F)c(F)c2)CC1', '0'],
#  ['Fc1cccc2c(-c3nc(CN4CCCC4)cs3)cn(CC3CCOCC3)c12', '1'],
#  ['COc1ccc(C(=O)N(c2cc(C)ccn2)C2CCN(c3cc(N)ccn3)CC2)cc1', '1'],
#  ['CN1CCC(CNc2ccn3ncc(-c4cccc(OC(F)(F)F)c4)c3n2)CC1', '1'],
#  ['Cc1ccccc1-n1nc(-c2c(-c3ccc(F)cc3)nn3c2NC[C@@H](CO)C3)ccc1=O', '0'],
#  ['CC1(C)Oc2ccc(NC(=O)c3ccc(Cl)cn3)cc2[C@@]2(COC(N)=N2)C12COC2', '1'],
#  ['O=C1COc2ccc(CNC34CCC(C[C@@]5(O)Cn6c(=O)c(F)cc7ncc(F)c5c76)(CC3)OC4)nc2N1',
#   '0'],
#  ['CN1Cc2cc(Cl)ccc2-n2c(nnc2C2CCN(c3ccccn3)CC2)C1', '1'],
#  ['Cc1nc2ccccc2n1C1CC2CCC(C1)N2CCC1(c2cccc(F)c2)CCN(C(=O)c2cc(S(N)(=O)=O)c(Cl)cc2F)CC1',
#   '0'],
#  ['Cc1nccn1Cc1cn(-c2ccc(F)c(C(C)(F)F)c2)nn1', '1'],
#  ['CN1CCC(c2ccc(Nc3ncc4c(=O)n(-c5c(Cl)cccc5Cl)ccc4n3)cc2)CC1', '1'],
#  ['CNCc1cc(Cl)ccc1Oc1ccc(Cl)c(Cl)c1', '1'],
#  ['CNCc1cc(C(F)(F)F)ccc1Oc1ccc(Cl)c(Cl)c1', '1'],
#  ['CN1CCO[C@H](c2ccccc2)[C@@H](c2ccc3ccccc3c2)C1', '1'],
#  ['c1ncc(-c2cnc3nc(N4CCC(N5CCCCC5)CC4)sc3c2)cn1', '0'],
#  ['O=c1cc([C@H]2CCN[C@@H](CCc3ccccc3)C2)o[nH]1', '0'],
#  ['CC(=O)Nc1ccc(-c2cnc3nc(N4CCC(N5CCCCC5)CC4)sc3c2)cn1', '0'],
#  ['Cc1nccnc1[C@@H](O)c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)cc(F)c23)c1', '0'],
#  ['CC1(C)Cc2c(ccc3[nH]ncc23)[C@@H](c2ccc(NC3CN(CCCF)C3)cn2)N1CC(F)F', '1'],
#  ['CC(C)(C#N)c1cnc(N2CCN(C(=O)[C@@H]3CCCC[C@H]3C(=O)NC3(C#N)CC3)CC2)s1', '0'],
#  ['COc1cnc(C(O)c2ccc(F)c(-c3ncnc4cc(N5CCOCC5)ccc34)c2)c(Cl)c1', '0'],
#  ['COc1nnc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)c2ccncc12', '0'],
#  ['Cc1cccc(C)c1[C@]1(O)CC[C@@H](N2CC(NC(=O)CNC(=O)c3cccc(C(F)(F)F)c3)C2)CC1',
#   '1'],
#  ['c1ccc(Cc2ncc3c(n2)CCNCC3)cc1', '0'],
#  ['CC#C[C@@H](c1ccc(Oc2ccc(C(F)(F)F)cc2OC(F)F)cc1)c1oc(=O)[nH]c1O', '1'],
#  ['CC(C)(C)c1nccn1Cc1cn(-c2ccc(F)c(C(F)F)c2)nn1', '1'],
#  ['COC1CCN(Cc2csc(-c3cn(CC4CCOCC4)c4c(Cl)cccc34)n2)CC1', '1'],
#  ['CCc1ncc([C@H]2CC[C@@H](N3CC(NC(=O)CNc4nn(C)c5ccc(C(F)(F)F)cc45)C3)CC2)s1',
#   '0'],
#  ['COc1cc(OC)c(F)c(COc2cnc(Nc3ccc(N4CCC(N5CCN(C)CC5)CC4)nc3)nc2)c1F', '1'],
#  ['COc1cc(OC2CN(C(C)=O)C2)ccc1Nc1ncc(Cl)c(-c2cnc3ccccn23)n1', '0'],
#  ['Cc1c(C#N)cccc1[C@H]1CN2CCN(C(=O)Cc3ccc(-n4cnnn4)nc3)C[C@H]2CO1', '1'],
#  ['CN(C)C(=O)c1cccc(-c2ncccc2CC(c2ccnc(N)n2)c2cccnc2F)c1', '0'],
#  ['CN(C)C(=O)[C@H]1CC2(CCN(c3cc(N)ccn3)CC2)c2ccccc21', '1'],
#  ['COc1cccc(N2CCN(Cc3nc4c5cccc(OC)c5nc(N)n4n3)[C@H](C)C2)c1', '1'],
#  ['Fc1cccc(Oc2ccc(F)c(N3CCC4(CC3)CNCCO4)c2)c1', '1'],
#  ['Cc1nccnc1C(O)c1cc(-c2ncnc3cc(N4CCOCC4)cnc23)c(F)cc1Cl', '0'],
#  ['COc1ccc([C@H](O)c2ccc(F)c(-c3ncnc4cc(N5CCOCC5)ccc34)c2)nn1', '0'],
#  ['COc1ccc2ncc(=O)n(CCN3CC[C@H](NCc4cc5c(cn4)OCCO5)[C@@H](F)C3)c2c1', '0'],
#  ['O=C1COc2ccc(CNC34CCC(CCc5c(F)cnc6ccc(OCCCO)nc56)(CC3)OC4)nc2N1', '1'],
#  ['OC(c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)c(F)cc1F)c1ncnc2c1CCNC2', '0'],
#  ['OC(CNCC(O)C1CCc2cc(F)ccc2O1)C1CCc2cc(F)ccc2O1', '1'],
#  ['COc1ccc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2F)c(F)c1', '1'],
#  ['Cc1nc2c(n1C1CC3CCC(C1)N3CC[C@H](NC(=O)C1CCC(F)(F)CC1)c1ccsc1)CCN(C(=O)C(C)C)C2',
#   '1'],
#  ['O=C(NCCN1CCCC1)c1cccn2c(=O)c3ccc4ccccc4c3nc12', '1'],
#  ['Cc1c(CNC2CCCC2)nn(-c2ccc(Cl)cc2Cl)c1-c1ccc(Cl)cc1', '1'],
#  ['CC[C@](O)(c1cn(Cc2ccc3c(-c4cccc(F)c4)c(C(N)=O)sc3c2)nn1)C(F)(F)F', '0'],
#  ['O=c1[nH]ccc2nc(-c3ccc(CN4CCC(c5nnc(-c6cnccn6)[nH]5)CC4)cc3)c(-c3ccccc3)cc12',
#   '1'],
#  ['N#Cc1ccc2ccc(=O)n(CCN3CC[C@H](NCc4cc5c(cn4)OCCO5)[C@H](O)C3)c2c1', '0'],
#  ['CN(C)C(=O)C(CO)N(C)Cc1ccc2c(c1)CC[C@H](N1CCN(CCc3ccc(F)cc3)CC1=O)C2', '0'],
#  ['Cc1cccc(N2C[C@]3(CC[C@@H](c4nc5ccc(OC(F)(F)F)cc5[nH]4)CC3)OC2=O)n1', '1'],
#  ['Cc1ncc(/C=C2\\C[C@H]3[C@@H]4CC[C@H]5N(C)C(=O)C=C[C@]5(C)[C@H]4CC[C@]3(C)[C@H]2O)cn1',
#   '0'],
#  ['COc1cnc(C(O)c2ccc(F)c(-c3ncnc4cc(N5CCOCC5)ccc34)c2)c(Br)c1', '0'],
#  ['O[C@@H](c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1)c1nccnc1Cl', '0'],
#  ['Cc1coc([C@H]2C[C@H]3[C@@H](C)SC(N)=N[C@@]3(c3ccc(F)cc3F)CO2)n1', '1'],
#  ['Cc1cc(-n2cc(Cn3ccnc3C3CC3)nn2)ccc1F', '1'],
#  ['CCO[C@@H]1Cc2cc(C(F)(F)F)ccc2[C@H]1N1CCN(C2(C)CCN(C(=O)c3c(C)ncnc3C)CC2)C[C@@H]1C',
#   '1'],
#  ['COc1ccc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2F)cn1', '0'],
#  ['Cc1cc(CNc2nc(N)nc3ccn(Cc4ccc(C(F)(F)F)cn4)c23)no1', '1'],
#  ['Cc1nsc(-c2nnc3n2CCN(C(=O)c2ccccc2)[C@@H]3C)n1', '0'],
#  ['N#Cc1cc(-c2cnc3nc(N4CCC(N5CCCCC5)CC4)sc3c2)ccc1F', '1'],
#  ['Cc1cccnc1C(=O)N1CCC(C)(N2CCC(N(c3ccccc3)c3cccnc3)CC2)CC1', '1'],
#  ['CC(C)[C@@H](CN1CCC(C)(c2cccc(O)c2)CC1)NC(=O)[C@H]1Cc2ccc(O)cc2CN1', '0'],
#  ['CN1CCN(Cc2ccc3c(c2)Cc2c-3n[nH]c2-c2csc(C#CCOc3ccc(Cl)cc3)c2)CC1', '1'],
#  ['CC[C@@H](NC(=O)c1ccc(C#N)cc1)[C@@H]1[C@@H]2C[C@@H](n3cnc4ccc(C#N)cc43)C[C@@H]21',
#   '1'],
#  ['CC(C(=O)NC1(c2ccccc2)CCC(N2CCC3(CCOC3)CC2)CC1)c1cc(C(F)(F)F)cc(C(F)(F)F)c1',
#   '1'],
#  ['CNCC(Cc1ccccc1O)c1ccc2ccccc2c1', '1'],
#  ['COc1cc(OC)c2nccc(CCC34CCC(NCc5ccc6c(n5)NC(=O)CO6)(CC3)CO4)c2n1', '1'],
#  ['Cc1nc(C(=O)Nc2ccc([C@H]3CNCCO3)cc2)cs1', '0'],
#  ['CCn1c(C(O)c2ccc(F)c(-c3ncnc4cc(N5CCOCC5)ccc34)c2)cccc1=O', '0'],
#  ['Cc1ccc(F)c2[nH]c(-c3cncc(-c4cc(F)cc(C#N)c4)c3N3CC[C@H](N)C3)nc12', '1'],
#  ['O=S(=O)(c1cccc2cnccc12)N1CCCNCC1', '0'],
#  ['COc1cccc2nc(CCCN(C)CC[C@]3(OC(=O)C(C)C)C[C@H]4CCC[C@@H]3c3ccccc34)[nH]c12',
#   '1'],
#  ['Cn1nc(C(O)c2ccc(F)c(-c3ncnc4cc(N5CCOCC5)ccc34)c2F)ccc1=O', '0'],
#  ['NC1CC1COc1ccc2ncc(F)c(CCC34CCC(NCc5ccc6c(n5)NC(=O)CO6)(CC3)CO4)c2n1', '1'],
#  ['Cc1c(OCCNCCCF)ncnc1[C@@H]1c2[nH]c3ccccc3c2C[C@@H](C)N1CC(F)(F)CO', '1'],
#  ['CNC[C@H](c1ccc2ccccc2c1)[C@H](O)c1cccnc1', '0'],
#  ['COC1COCCC1N[C@@H]1C[C@H]2C[C@@H](OC)C[C@@]2(C(=O)N2CCc3ncc(C(F)(F)F)cc3C2)C1',
#   '0'],
#  ['CN1CCN(c2ccc3nc(N)n(CC(O)c4ccc(C(F)(F)F)cc4Cl)c3n2)CC1', '1'],
#  ['COc1ccc(OC[C@@H](C)NCCCF)cc1[C@@H]1c2[nH]c3ccccc3c2C[C@@H](C)N1CC(F)(F)CO',
#   '1'],
#  ['Cc1cn(CC(O)c2ccc(Cl)cc2Cl)c(N)n1', '0'],
#  ['CC(C)N(C)[C@@H]1CC[C@H](N2CC[C@H](NC(=O)c3cccc(C(F)(F)F)c3)C2=O)[C@H](CS(C)(=O)=O)C1',
#   '0'],
#  ['Cc1c2c(n3c1CCCN1CCC[C@@H]1CNc1cc-3ccc1C(N)=O)CC(C)(C)CC2=O', '1'],
#  ['C[C@@H]1Cc2c([nH]c3cc(F)ccc23)[C@@H](c2c(F)ccc(OCCNCCCF)c2F)N1CC(F)(F)CO',
#   '1'],
#  ['COc1cnc2ccc(=O)n(CCN3CCC(NCc4cnc(C)c(C#N)n4)CC3)c2c1', '0'],
#  ['FC1(F)CC1Cc1nnc2cc(-c3ccc4c(c3)CCO4)ccn12', '0'],
#  ['CC(C)c1ccc(S(=O)(=O)Nc2ccc([C@@]34C[C@@H]3CN(C)C4)cc2)cc1', '1'],
#  ['Fc1cccc(-c2ccn3c(CC4CC4(F)F)nnc3c2Cl)c1', '1'],
#  ['Nc1nc2cc3c(cc2s1)CCN(Cc1cccnc1)CC3', '1'],
#  ['CC(=O)N1Cc2cc(Cl)ccc2-n2c(nnc2C2CCN(c3ccccn3)CC2)C1', '0'],
#  ['CNCC1(O)CCN(c2nc(Oc3cccc(F)c3)cc(C(F)(F)F)n2)CC1', '1'],
#  ['OC(c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)ccc1Cl)c1ncnn2cccc12', '1'],
#  ['Clc1cccc(OC(c2cccnc2)[C@@H]2CCCNC2)c1Cl', '1'],
#  ['C[C@@H]1Cc2c(ccc3[nH]nc(F)c23)[C@@H](c2ccc(OC3CN(CCCF)C3)cn2)N1CC(F)(F)CO',
#   '1'],
#  ['C[C@@]1(c2nc(NC(=O)c3ccc(C#N)cn3)ccc2F)CS(=O)(=O)[C@@](C)(C(F)F)C(=N)N1',
#   '1'],
#  ['Cc1nc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ncc34)cnc2F)sc1C', '0'],
#  ['COC(C)(C)C#Cc1cnc2c(c1)[C@]1(COC(N)=N1)c1cc(-c3cccnc3F)ccc1O2', '0'],
#  ['NC(=O)N1CCN(Cc2ccc3c(c2)Cc2c-3n[nH]c2-c2csc(C#CCOc3ccccc3)c2)CC1', '1'],
#  ['OCC(c1ccccc1)N1CCOCC1', '0'],
#  ['O=c1[nH]c([C@@H]2CCCN2)nc2c1oc1ccc(Cl)cc12', '0'],
#  ['Cc1c(OCCN(C)CCCF)ccc(F)c1[C@@H]1c2[nH]c3ccccc3c2C[C@@H](C)N1C[C@H](C)C(=O)O',
#   '0'],
#  ['CN(CC(N)=O)Cc1nc(-c2cn(CC3CCOCC3)c3c(Cl)cccc23)no1', '0'],
#  ['Cc1nc2ccccc2n1C1CC2CCC(C1)N2CCC1(c2cccc(F)c2)CCN(C(=O)c2ccc(NS(C)(=O)=O)cc2Cl)CC1',
#   '1'],
#  ['O=C1COc2ccc(CNC34CCC(C[C@]5(O)Cn6c(=O)ccc7nc(Cl)c(F)c5c76)(CC3)OC4)nc2N1',
#   '0'],
#  ['O=C(NCC(=O)N1CC[C@H](N[C@H]2CC[C@@](O)(c3ccc(-c4ncco4)cn3)CC2)C1)c1cccc(C(F)(F)F)c1',
#   '0'],
#  ['Cc1ccc(Nc2nc3ccc(N4CCN(C)CC4)cc3[nH]2)nc1', '1'],
#  ['CCN(Cc1cc(C(F)(F)F)ccc1-c1cc(CC(=O)O)ccc1OC)C(=O)OCc1ccccc1', '0'],
#  ['Cc1ccc(OC(=O)N(CC(=O)O)Cc2cccc(OCc3nc(-c4cccc(Cl)c4)oc3C)c2)cc1', '1'],
#  ['CC[C@@H](C)[C@H](C(=O)O)N1C[C@H](CN2CCC(c3cc(Cc4ccc(C#N)cc4)nn3CC)CC2)[C@@H](c2cccc(F)c2)C1',
#   '0'],
#  ['O=C(CNC(=O)c1cccc(C(F)(F)F)c1)NC1CN([C@H]2CC[C@H](c3cnccn3)CC2)C1', '1'],
#  ['Cc1ncc(CN[C@@H]2CCN(CCn3c(=O)ccc4ncc(F)cc43)C[C@@H]2F)cc1C#N', '0'],
#  ['Cc1cnc(COc2nc(N)nc3ccn(Cc4ccccn4)c23)o1', '0'],
#  ['CO[C@@H]1COCC[C@@H]1N[C@@H]1CC[C@@](C(=O)N2CCN(c3cc(C(F)(F)F)ccn3)CC2)(C(C)C)C1',
#   '1'],
#  ['CCOC(=O)C(F)(F)CCOc1ccc2ncc(F)c(CCC34CCC(NCc5ccc6c(n5)NC(=O)CO6)(CC3)CO4)c2n1',
#   '0'],
#  ['COCC#Cc1cc(-c2[nH]nc3c2Cc2cc(CN4CCN(C)CC4)ccc2-3)cs1', '1'],
#  ['COC(=O)[C@H]1[C@@H](OC(=O)c2ccccc2)C[C@@H]2CC[C@H]1N2C', '1'],
#  ['Cc1ccc([C@@H]2CN(C(=O)[C@H]3CC[C@H](CN)CC3)C[C@H]2c2ccc(C#N)cc2)cc1', '1'],
#  ['COc1cc(C2(c3cccc(-c4cncnc4)c3)N=C(N)c3c(F)cccc32)ccn1', '1'],
#  ['CCOc1ccc(Cc2cc(C3CCN(C[C@H]4CN([C@@H](C(=O)O)[C@@H](C)CC)C[C@@H]4c4cccc(F)c4)CC3)n(CC)n2)cc1',
#   '0'],
#  ['Cc1nccn1Cc1cn(-c2ccc(Cl)c(C(F)(F)F)c2)nn1', '1'],
#  ['COc1cnc2ccc(=O)n(CCN3CCC(c4nc5cc(Cl)c(F)cc5[nH]4)CC3)c2c1', '1'],
#  ['N#Cc1ccc(Cn2cncc2CN[C@H]2CCN(C(=O)c3cncc(Br)c3)C2=O)cc1', '1'],
#  ['CCC(NCCCC[C@@H](Oc1cc(C)c(F)c(C)c1)C(=O)NO)c1ccc(F)cc1', '1'],
#  ['Cc1nccnc1C(C(N)=O)c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)ccc1Cl', '0'],
#  ['COc1cnc2ccc(=O)n(CCN3CCC(c4c[nH]c5ccc(C#N)cc45)CC3)c2c1', '1'],
#  ['CCNC(=N)NC(=O)Nc1c(CC)cc(NS(=O)(=O)c2ccccc2)cc1CC', '0'],
#  ['OC(c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1)c1nccnc1C(F)(F)F', '0'],
#  ['CN(C)c1cccc([C@]2(O)CC[C@@H](N3CC(NC(=O)CNC(=O)c4cccc(C(F)(F)F)c4)C3)CC2)c1',
#   '0'],
#  ['C[C@@H]1Cc2c(ccc3[nH]ncc23)[C@@H](c2ccc(NC3CN(CCCF)C3)c(F)n2)N1CC(F)F',
#   '1'],
#  ['Cn1cnc2ncnc(C(O)c3cc(-c4ncnc5cc(N6CCOCC6)ccc45)c(F)cc3Cl)c21', '0'],
#  ['CC1(C)CC(NC(=O)CC(O)C(F)(F)F)c2cc(-c3ccc(Cl)cc3)c(-c3ccc(Cl)cc3Cl)nc2O1',
#   '1'],
#  ['Cc1cccc(-c2nnc3n2CCN(C(=O)c2ccc(-c4ccccc4)cc2)[C@@H]3C)n1', '0'],
#  ['COc1ccc(C2(c3cccc(-c4cncnc4)c3)N=C(N)C(C(C)C)=N2)cc1', '0'],
#  ['OC(c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1)c1c(F)cncc1F', '0'],
#  ['Cc1oc(-c2ccc(Cl)cc2)nc1CCOc1cccc(C[C@@H]2C(=O)N(c3ccc(C(C)(C)C)cc3)[C@@H]2C(=O)O)c1',
#   '1'],
#  ['CCn1cncc1Cn1cc(-c2ccc(Cl)c(C(F)F)c2)cn1', '1'],
#  ['Cn1ncc2c(C(O)c3cc(-c4ncnc5cc(N6CCOCC6)ccc45)c(F)cc3F)ncnc21', '0'],
#  ['Cc1csc(-c2nnc3n2CCN(C(=O)c2ccc(-c4cccs4)cc2)[C@@H]3C)n1', '1'],
#  ['CC(C)n1c(N2CCOC(CN)C2)nc2c([N+](=O)[O-])c(Br)c(Br)cc21', '1'],
#  ['CN(CCCC(=O)NC1COC1)C(=O)c1ccc2c(c1)c1c(n2C)CC[C@@H](C2CCOCC2)C1', '0'],
#  ['COc1ccc2ncc(F)c(CCC34CCC(NCc5cc(C)c6c(n5)NC(=O)CO6)(CC3)CO4)c2n1', '1'],
#  ['CN(C)C(=O)[C@@H]([C@H]1CC[C@H](c2ccc3ncnn3c2)CC1)[C@H](N)C(=O)N1CCC(F)(F)C1',
#   '0'],
#  ['CC1(C)CN2C(CS/C(=N\\C3CCCCC3)NC3CCCCC3)=CSC2=N1', '1'],
#  ['O=C(CCCCCCC(=O)Nc1ccc2ccnc(Nc3cccc(Cl)c3F)c2c1)NO', '0'],
#  ['CN1CCC(COCc2cc(C(F)(F)F)cc(N3CCC(C#N)CC3)n2)(c2ccc(F)cc2)CC1', '1'],
#  ['N#CCC1(n2cc(-c3ccnc4[nH]ccc34)cn2)CN(S(=O)(=O)N2CCCC2)C1', '0'],
#  ['OC(c1ccc(-c2ncnc3cc(N4CCOCC4)ccc23)s1)c1nccs1', '0'],
#  ['Fc1ccc(-c2ccn3c(CC4CC4(F)F)nnc3c2)cc1', '0'],
#  ['CN(C)[C@H]1CC[C@](c2ccccc2)(N2CCC(c3cc(C(F)(F)F)cc(C(F)(F)F)c3)C2=O)CC1',
#   '1'],
#  ['COc1cc(Cl)c(-c2nc(SCC(=O)N(C)C)nc3[nH]cc(C#N)c23)cc1O', '0'],
#  ['CNc1cc(F)cc2c1[nH]c1nc(Oc3cnc(C)nc3)nc(N3CC(=C(C)CN)C3)c12', '0'],
#  ['Cc1cc(C#N)cnc1C(=O)Nc1ccc(F)c([C@]2(C)CS(=O)(=O)[C@@](C)(C(F)F)C(=N)N2)n1',
#   '0'],
#  ['CN=C(N)NC(=O)Nc1c(C)cccc1C', '0'],
#  ['CNS(=O)(=O)Nc1ccc2ccc3ncc(-c4cnn(C)c4)cc3c(=O)c2c1', '0'],
#  ['Cn1nc(NCC(=O)NC2CN([C@H]3CC[C@@H](C(N)=O)CC3)C2)c2cc(C(F)(F)F)ccc21', '0'],
#  ['Cn1nccc1-n1cc(-c2ccc(F)c(Cl)c2)cn1', '1'],
#  ['CC[C@H]1OC(=O)[C@H](C)C(=O)[C@H](C)[C@@H](O[C@@H]2O[C@H](C)C[C@H](N(C)C)[C@H]2O)[C@](C)(O)C[C@@H](C)C(=O)[C@H](C)[C@H]2N(C3CN(Cc4c(O)cnc5cccnc45)C3)C(=O)O[C@]12C',
#   '0'],
#  ['N[C@@H]1COC[C@H]1Oc1ccc2ncc(F)c(CCC34CCC(NCc5ccc6c(n5)NC(=O)CO6)(CC3)CO4)c2n1',
#   '1'],
#  ['COc1nccnc1C(C(N)=O)c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)c(F)cc1Cl', '0'],
#  ['CC(C)S(=O)(=O)N[C@H]1CN(C)C[C@@H]1c1ccc(-c2ccc(F)nc2)cc1', '1'],
#  ['COc1cc(Cc2cnc(N)nc2N)cc(OC)c1OC', '0'],
#  ['O=C(CNC(=O)c1cccc(C(F)(F)F)c1)NC1CN([C@H]2CC[C@H](c3ccc(O)cc3)CC2)C1', '1'],
#  ['CCS(=O)(=O)c1cc2cc(C[C@](O)(CC(C)(C)c3ccccc3C(N)=O)C(F)(F)F)[nH]c2cn1',
#   '0'],
#  ['COc1cc(N2CCN(C(=O)[C@@H](C)O)CC2)ccc1Nc1ncc(Cl)c(-c2cnc3ccccn23)n1', '1'],
#  ['CN(C)c1nc(=O)n(-c2cccnc2)c2cc(Cl)ccc12', '0'],
#  ['N[C@H](C(=O)N1CCCC1)[C@H]1CC[C@H](NC(=O)OCc2ccccc2)CC1', '0'],
#  ['C[C@@H]1Cc2c([nH]c3ccccc23)[C@@H](c2c(F)cnc(OCCNCCCF)c2Cl)N1CC(F)(F)CO',
#   '1'],
#  ['COCCn1cc(-c2c(C)nc3c(N4CCOCC4)nccn23)cn1', '1'],
#  ['CCCCN1CCC2(CC1)OC(OC)c1c2cnn1-c1ccccc1', '1'],
#  ['CC(C)(O)c1ccc(C(Cc2ccc(=O)[nH]c2)c2ccc(OC(F)F)c(OC3CC3)c2)cn1', '0'],
#  ['CO[C@@H]1COCC[C@@H]1N(C)[C@@H]1CC[C@@](C(=O)N2CCN(c3cc(C(F)(F)F)cnn3)CC2)(C(C)C)C1',
#   '0'],
#  ['OCCN(CCO)Cc1csc(-c2cn(CC3CCOCC3)c3c(Cl)cccc23)n1', '1'],
#  ['O=C(NCC(=O)N1CC[C@H](N[C@H]2CC[C@@](O)(c3ccc(-c4cccnc4)cn3)CC2)C1)c1cccc(C(F)(F)F)c1',
#   '0'],
#  ['COc1ccc(-n2cnc3c(-c4ccccc4F)csc3c2=O)cc1', '0'],
#  ['CONC(=O)N(Cc1ccsc1)C1CCN([C@H](C)CCNC(=O)c2c(C)cc(C#N)nc2Cl)CC1', '1'],
#  ['CN1C(=O)C=C[C@]2(C)[C@H]3CC[C@]4(C)[C@@H](O)/C(=C/c5ccccc5)C[C@H]4[C@@H]3CC[C@@H]12',
#   '1'],
#  ['Cc1cc(Cn2cc(-c3ccc(Cl)cc3)cn2)n(C)n1', '1'],
#  ['O=C1CN(CCc2ccc(F)cc2)CCN1[C@H]1CCc2cc(Cn3ccnc3)ccc2C1', '1'],
#  ['Fc1ccc(C(OC(F)F)c2nccs2)cc1-c1ncnc2cc(N3CCOCC3)ccc12', '1'],
#  ['c1ccc(COc2ccc(CCNc3ccncc3)cc2)cc1', '1'],
#  ['CN1CCc2cc3nc(N)sc3cc2CC1', '0'],
#  ['CN1C2CC[C@@H]1C[C@H](OC(=O)c1ccccc1)C2C(=O)O', '0'],
#  ['O=C1COc2ccc(CNC34CCC(C[C@]5(O)Cn6c(=O)ccc7ncc(F)c5c76)(CC3)OC4)nc2N1', '0'],
#  ['OC(c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)ccc1Cl)c1ncnc2ccsc12', '0'],
#  ['C[C@@H]1Cc2c([nH]c3ccccc23)[C@@H](c2cc(F)cc(OCCNCCCF)c2F)N1CC(F)(F)F', '1'],
#  ['COc1ccc([C@@H](C)N[C@@H]2CC[C@@H](C(=O)N3CCC(c4ccccc4)(c4ccc(Cl)nc4)CC3)C(C)(C)C2)cc1',
#   '1'],
#  ['CN1C[C@@H]2C[C@H]1CN2c1ncc(-c2ccc3sccc3c2)cn1', '1'],
#  ['Nc1nc2c(C(=O)N[C@@H]3CN4CCC3CC4)cccc2o1', '0'],
#  ['O=C(N1CCc2ncc(C(F)(F)F)cc2C1)[C@@]12CCC[C@@H]1C[C@@H](NC1CCOCC1)C2', '0'],
#  ['CC(C)S(=O)(=O)N[C@H]1CN(C)C[C@@H]1c1ccc(-c2cccnc2F)cc1', '1'],
#  ['O=C(CNc1n[nH]c2ccc(C(F)(F)F)cc12)NC1CN([C@H]2CC[C@@H](O)CC2)C1', '0'],
#  ['CCC(NC(=O)c1ccc(Cl)cc1)[C@H]1[C@@H]2C[C@@H](n3cnc4cnccc43)C[C@@H]21', '1'],
#  ['Cc1cc(Nc2ccccc2)nc(NCc2ccccn2)n1', '1'],
#  ['O=C(CCc1ccccc1)NC1CCc2ccc(CCN3CCN(c4nsc5ccccc45)CC3)cc21', '1'],
#  ['C[C@@H]1Cc2c(ccc3[nH]ncc23)[C@@H](c2c(F)cc(NC3CN(CCCF)C3)cc2F)N1CC(F)(F)F',
#   '1'],
#  ['Cc1cc(C(=O)N[C@@H]2CC(C)(C)Oc3nc(-c4ccc(Cl)cc4Cl)c(-c4ccc(Cl)cc4)cc32)[nH]n1',
#   '1'],
#  ['N#Cc1ccc(C(=O)Nc2ccc([C@H]3CNCCO3)cc2)cn1', '0'],
#  ['Cc1c2c(n3c1CCCN1CCOC[C@@H]1CNc1cc-3ccc1C(N)=O)CC(C)(C)CC2=O', '1'],
#  ['Fc1ccc(-c2cnc3nc(N4CCC(N5CCCCC5)CC4)sc3c2)cn1', '1'],
#  ['Nc1cccc(C(Cc2cccnc2-c2cccc(C(F)(F)F)c2)c2cccnc2)n1', '0'],
#  ['CNC[C@H](c1ccc2ccccc2c1)[C@@H](O)c1ccccc1F', '0'],
#  ['COc1cc(CCC(C)(C)N2Cc3ccc(F)cc3C2)ccc1OCCO', '1'],
#  ['O=C(O)[C@H]1CC[C@H](OC2CCN(c3ccc(-c4nc5cc(Cl)ccc5[nH]4)cn3)CC2)CC1', '1'],
#  ['CNC(C)C1(c2ccc(Cl)c(Cl)c2)CCCCC1', '0'],
#  ['O=P(Nc1cccnc1)(c1ccccc1)c1ccccc1', '0'],
#  ['c1ccc([C@@H]([C@H](c2ccccc2)N2CCCC2)N2CCCC2)cc1', '0'],
#  ['CN(C)Cc1ccc(C(F)(F)F)cc1Oc1ccc(Cl)c(Cl)c1', '1'],
#  ['O=C(N[C@@H]1C[C@H]2CCC[C@@]2(C(=O)N2CCc3ncc(C(F)(F)F)cc3C2)C1)C1CCOCC1',
#   '0'],
#  ['CS(=O)(=O)NCC1CC2(c3ccc(F)cc3)NC1CCC2NCc1cc(OC(F)(F)F)ccc1OC1CC1', '1'],
#  ['C[S+]([O-])c1ccc(-c2cnc3ccc(-c4cccc([S+](C)[O-])c4)nn23)cc1', '1'],
#  ['COc1cnc2ccc(=O)n(CCN3CCC(c4nc5cc(C(F)(F)F)ccc5[nH]4)CC3)c2c1', '1'],
#  ['O=C(NC[C@@H]1[C@H]2C[C@H](n3cnc4cc(F)c(F)cc43)C[C@@H]12)c1ccc(Cl)cc1', '1'],
#  ['Cc1oc(-c2cccc(Cl)c2)nc1CCOc1cccc(C[C@@H]2C(=O)N(c3ccc(C(C)(C)C)cc3)[C@@H]2C(=O)O)c1',
#   '1'],
#  ['O=c1ccc2ccc(F)c3c2n1CC3C[C@H]1OC[C@H](NCc2ccc3c(c2)OCCO3)CO1', '0'],
#  ['CNC[C@H](c1ccc2ccccc2c1)[C@H](O)c1ccccc1C', '1'],
#  ['O=c1c2cnc(Nc3ccc(N4CCNCC4)c(CO)c3)nc2ccn1-c1c(Cl)cccc1Cl', '1'],
#  ['CC(=O)N[C@H]1CC[C@H]([C@H](C)[C@H](N)C(=O)N2CC[C@H](F)C2)CC1', '0'],
#  ['CNCC(c1ccc(Br)c(Cl)c1)[C@H](O)c1ccccc1', '1'],
#  ['O=c1ccc2ncc(F)c3c2n1C[C@@]3(O)CN1CCC(NCc2cc3c(cn2)OCCO3)CC1', '0'],
#  ['O=C(NCCN1CC[C@@H](F)C1)c1cccn2c(=O)c3ccc4ccccc4c3nc12', '1'],
#  ['CC1(C)Cc2c(ccc3[nH]ncc23)[C@@H](c2ccc(NC3CN(CCCF)C3)cn2)N1CC(F)(F)F', '1'],
#  ['CN(C)CCCNC(=O)c1cccn2c(=O)c3ccc4ccccc4c3nc12', '1'],
#  ['OC(c1cccnc1-c1cccc(Cl)c1)C(c1cccnc1)c1ncco1', '0'],
#  ['C[C@@H]1CCC[C@H](C)N1CCNc1cn(Cc2ccc(F)cc2)nn1', '1'],
#  ['COc1ccc(OC(F)(F)F)cc1CNC1CCC2CCC1(c1ccccc1)N2', '1'],
#  ['Cc1ccccc1C1CCN(C[C@@H]2CCc3c(C)cccc3[C@@H](O)C2)CC1', '1'],
#  ['COC1COCCC1N[C@@H]1C[C@H]2C[C@@H](O)C[C@@]2(C(=O)N2CCc3ncc(C(F)(F)F)cc3C2)C1',
#   '0'],
#  ['COc1ccc(CC(=O)N2CCC3(CC2)CN([C@@H]2CCc4cc(-c5ncccn5)ccc42)C3)cc1', '1'],
#  ['COc1cc2c(c(N3CCN(C)CC3)c1)O[C@@H](C(=O)Nc1ccc(N3CCOCC3)cc1)CC2', '1'],
#  ['CC[C@@H](CC(=O)NCC1CCCCC1)n1c(N)nc2cc(Cl)ccc21', '1'],
#  ['Cc1ncc(-c2ccnc(Nc3ccc(C(=O)NC4CC4)cc3)n2)n1C(C)C', '1'],
#  ['COc1nc2c(CCC34CCC(NCc5ccc6c(n5)NC(=O)CO6)(CC3)CO4)c(F)cnc2cc1F', '1'],
#  ['c1ccc([C@@H]2OCCNC[C@H]2c2ccc3ccccc3c2)cc1', '1'],
#  ['CC(C)(C)COc1ccc2c(c1)[C@]1(COC(N)=N1)c1cc(-c3ccc(F)nc3)ccc1O2', '1'],
#  ['FCCc1nccn1Cc1cn(-c2cc(F)cc(C(F)F)c2)cn1', '1'],
#  ['N/C(CC(O)c1cc2c(F)cc(F)cc2c2cc(C(F)(F)F)ccc12)=N\\N=C\\c1ccc(F)cc1', '1'],
#  ['NC1=NC2(CO1)c1cc(-c3cncnc3)ccc1OCC21CCC1', '1'],
#  ['Cc1cc(NCc2c(C)cccc2C)c2cccc(C(N)=O)c2n1', '1'],
#  ['OC(c1cccnc1)(c1cccnc1)C(c1ccccc1)N1CCC1', '1'],
#  ['COc1ccc(NC(=O)/C=C/CN(C)C)cc1Nc1ncc(Cl)c(-c2cnn3ccccc23)n1', '1'],
#  ['O=C(O)CCCCOc1ccc2ncc(F)c(CCC34CCC(NCc5ccc6c(n5)NC(=O)CO6)(CC3)CO4)c2n1',
#   '0'],
#  ['CS(=O)(=O)c1ccc(-n2cc(Cl)c(OC3CCN(c4ncc(Cl)cn4)CC3)cc2=O)c(F)c1', '1'],
#  ['N[C@H](C(=O)N1CCC(F)(F)C1)[C@H]1CC[C@H](NC(=O)OCc2ccccc2)CC1', '0'],
#  ['OC(c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)ccc1Cl)c1ncnc2sccc12', '0'],
#  ['CC(Cc1ccccc1)NCCC(c1ccccc1)c1ccccc1', '1'],
#  ['Cc1ncc(-c2c(C)c(CN[C@H]3CC[C@@H](F)C3)nn2-c2ncccc2Cl)cc1F', '0'],
#  ['COCc1ccc2c3nc(N4CCC[C@@H](N)C4)n(Cc4ccccc4Cl)c3c(=O)n(C)c2c1', '1'],
#  ['CNC(=O)N1C[C@H]2[C@H](C)[C@@H](C)[C@H](/C=C/c3ccc(-c4ccccc4C#N)cn3)[C@@H]3[C@@H](C)OC(=O)[C@@]32C1',
#   '0'],
#  ['CN1[C@@H]2CCC[C@@H]1CC(NC(=O)c1cccc3oc(C4CC4)nc13)C2', '1'],
#  ['C[C@]1(COc2ccc(OC(F)(F)F)cc2)CCn2cc([N+](=O)[O-])nc2O1', '1'],
#  ['O=C(O)COc1ccc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)nn1', '0'],
#  ['O=C(NC1CC1)c1ccc(OCCCC2CC2CCCC2CCN(c3ncc(Cl)cn3)CC2)cc1F', '0'],
#  ['O=C(NC1CCCCC1)[C@H](C1CCCCC1)n1c(-c2ccc(Cl)cc2)nc2cc(F)c(F)cc21', '1'],
#  ['CC(C)[C@H](CC(=O)[C@H]1Cc2ccc(C(N)=O)cc2CN1)CN1CC[C@@](C)(c2cccc(O)c2)[C@@H](C)C1',
#   '0'],
#  ['Cc1cn(C2=CC[C@H]3[C@@H]4CC=C5C[C@@H](NC(=O)c6ccncc6)CC[C@]5(C)[C@H]4CC[C@]23C)cn1',
#   '1'],
#  ['NC1=N[C@@]2(CO1)c1cc(-c3cccnc3F)ccc1Oc1c2cc(C2CCOCC2)nc1F', '0'],
#  ['CNCC(CCc1ccccc1)[C@H](O)c1ccccc1', '1'],
#  ['Cc1cc2c(s1)Nc1ccccc1N=C2N1CCN(C)CC1', '1'],
#  ['COC(=O)c1ccc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)nn1', '0'],
#  ['CNCC(c1ccc2ccccc2c1)[C@H](CO)c1ccccc1', '0'],
#  ['NC1=NC2(CO1)c1cc(-c3cncc(C4CC4)c3)ccc1OCC21CC1', '1'],
#  ['CC[C@@H](NC(=O)c1ccc(Cl)cc1)[C@H]1[C@@H]2C[C@@H](n3cnc4ccc(C#N)cc43)C[C@@H]21',
#   '1'],
#  ['N#Cc1ccc2nc([C@H]3CC[C@]4(CC3)CN(c3ccc(F)cc3)C(=O)O4)[nH]c2c1', '1'],
#  ['Clc1cc(COCC2(c3ccccc3)CCNCC2)cc(Cl)n1', '0'],
#  ['CCn1nc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)ccc1=O', '0'],
#  ['Cn1nccc1Cn1cc(-c2ccc(Cl)c(OC(F)F)c2)cn1', '1'],
#  ['Cc1cc(O[C@H](CCCCNCc2ccc(F)cc2)C(=O)NO)cc(C)c1F', '1'],
#  ['Cc1cc(C)n(-c2cc(NC(=O)CN3CCCN(C)CC3)nc(-c3ccc(C)o3)n2)n1', '1'],
#  ['COc1cc(N2CCN(C(N)=O)CC2)ccc1Nc1ncc(Cl)c(-c2cnc3ccccn23)n1', '0'],
#  ['CN1[C@@H]2CC[C@H]1c1c(sc(NC(=O)Nc3ccc(Cl)cc3)c1C(N)=O)C2', '1'],
#  ['COc1cnccc1[C@H]1CC[C@@H](N2CC(NC(=O)CNc3ncnc4ccc(C(F)(F)F)cc34)C2)CC1',
#   '1'],
#  ['CNC[C@H](c1ccc2ccccc2c1)[C@H](O)c1ccncc1', '1'],
#  ['OC(c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1)c1nccc2ccoc12', '1'],
#  ['CCCCCOC(=O)N1CCN(C(=O)[C@H](CCC(=O)O)NC(=O)c2cc(N3CCC(C(=O)N4CCCC4)CC3)cc(-c3ccccc3)n2)CC1',
#   '0'],
#  ['CCOC(=O)CCCOc1ccc2ncc(F)c(CCC34CCC(NCc5ccc6c(n5)NC(=O)CO6)(CC3)CO4)c2n1',
#   '1'],
#  ['Cc1cc(Cn2cc(-c3ccc(Cl)c(C(F)(F)F)c3)cn2)n(C)n1', '1'],
#  ['O=C(Nc1ccc([C@H]2CNCCO2)cc1)c1cnc(Cl)c(Cl)c1', '1'],
#  ['Cc1cnc(Nc2cc(N3CCN(C)CC3)nc(N[C@@H](C)c3ccc(F)cn3)n2)s1', '1'],
#  ['O=C(O)C[C@H]1CC[C@H](c2ccc(NC(=O)c3nnc(Nc4ccc(F)c(F)c4)o3)cc2)CC1', '0'],
#  ['O=C1COc2ccc(CNC34CCC(CCc5ccnc6ccc(C(F)(F)F)nc56)(CC3)OC4)nc2N1', '1'],
#  ['CN1C[C@@H]2C[C@H]1CN2c1ccc(-c2ccc3[nH]c(C(F)(F)F)cc3c2)nn1', '1'],
#  ['c1cncc(-c2ccccc2CC(c2cccnc2)c2cccnc2)c1', '0'],
#  ['CN(C)C(=O)c1cccc2c1CN(C(C)(C)CCc1ccc(O)c(OC(C)(C)C)c1)C2', '1'],
#  ['C[C@H]1C[C@H]2CSC(NC(=O)c3ccccc3)=N[C@@]2(c2nc(NC(=O)c3ccc(Cl)cn3)cs2)CO1',
#   '1'],
#  ['Nc1nc2ccc(OCC(F)(F)F)nc2n1CC(O)c1ccc(C(F)(F)F)cc1Cl', '0'],
#  ['C[C@H](CCc1ccc(O)c(OC(C)(C)C)c1)N1Cc2c(F)ccc(F)c2C1', '0'],
#  ['COC(=O)c1coc(CN2CCN(C(=O)CC(c3ccc(F)cc3)c3ccc(C(F)(F)F)cc3)CC2)n1', '1'],
#  ['O=C1COc2ccc(CN[C@@H]3CCN(CCn4c(=O)ccc5ncc(Oc6cccnc6)cc54)C[C@@H]3F)nc2N1',
#   '0'],
#  ['C[C@@H](NCc1cc([C@]2(C)CCSC(N)=N2)c(F)cc1F)C(F)(F)F', '1'],
#  ['COc1cccc(C(=O)Cn2c(=O)c3c(c(C#N)c(N4CCC[C@H](N)C4)n3CC=C(C)C)n(C)c2=O)c1',
#   '1'],
#  ['OC(c1cccnn1)c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)c(F)cc1Cl', '0'],
#  ['CC(C)(C)Oc1cc(CCC(C)(C)N2Cc3cccc(F)c3C2)ccc1O', '1'],
#  ['O=C1CSc2ccc(CNC34CCC(C[C@]5(O)Cn6c(=O)ccc7ncc(F)c5c76)(CC3)OC4)nc2N1', '0'],
#  ['COc1cc(-c2cnc3nc(N4CCC(N5CCCCC5)CC4)sc3c2)ccn1', '1'],
#  ['CCc1nccn1Cc1cn(-c2ccc(F)c(C(F)F)c2)nn1', '1'],
#  ['Fc1ccc(Nc2n[nH]c3cc(OC(F)(F)F)cnc23)cc1F', '0'],
#  ['Cc1ccc([C@H]2CC[C@@H](N3CC(NC(=O)CNc4n[nH]c5ccc(C(F)(F)F)cc45)C3)CC2)cn1',
#   '0'],
#  ['Fc1ccc(N(CCNCCc2ccccc2)c2ccc(F)cc2)cc1', '1'],
#  ['CN1c2nc(-c3ccc(Cl)cc3Cl)c(-c3ccc(Cl)cc3)cc2C(C(=O)NCO)CC1(C)C', '1'],
#  ['COc1cc(NC2CN(CCCF)C2)ccc1[C@@H]1c2ccc3[nH]ncc3c2C[C@@H](C)N1CC1(F)CC1',
#   '1'],
#  ['Cc1c([C@H]2CN3CCN(C(=O)Cc4ccc(-n5cnnn5)nc4)C[C@H]3CO2)ccc(F)c1C#N', '1'],
#  ['CC[C@](O)(c1cn(Cc2ccc3c(-c4ccc(F)cc4)c(C(=O)O)sc3c2)nn1)C(F)(F)F', '0'],
#  ['Cc1ccc(Nc2nccc3ccc(NC(=O)CCCCCCC(=O)NO)cc23)cc1', '0'],
#  ['Nc1nc2cc3c(cc2s1)CCN(CC(F)(F)F)CC3', '0'],
#  ['CCc1[nH]ncc1Cn1cc(-c2ccc(F)c(OC(F)F)c2)cn1', '1'],
#  ['O=C1COc2ccc(CNC34CCC(CCc5c(F)cnc6ccc(OCC(CO)CO)nc56)(CC3)OC4)nc2N1', '1'],
#  ['COc1cc2c(cc1OC(C)C)[C@H](c1ccc(Cl)cc1)N(c1ccc(N(C)C[C@H]3CC[C@H](N4CCNC(=O)C4)CC3)cc1)C(=O)C2',
#   '1'],
#  ['O=c1ccc2ncc(F)c3c2n1C[C@@]3(O)CC12CCC(NCc3cc4c(cn3)S(=O)(=O)CCO4)(CC1)CO2',
#   '0'],
#  ['Cn1cc(Cn2cc(-c3ccc(Cl)c(OC(F)F)c3)cn2)cn1', '1'],
#  ['Cc1nccnc1C(O)c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)c(F)cc1Cl', '0'],
# ...
#   '1'],
#  ['Cc1cc(Nc2ccccc2)nc(NCc2ccc3c(c2)OCO3)n1', '1'],
#  ['COc1ccc(C(O)(c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)C(F)F)nn1', '0'],
#  ['CS(=O)(=O)N1CC(CC#N)(n2cc(-c3ccnc4[nH]ccc34)cn2)C1', '0'],
#  ['CN1C(=O)C=C[C@]2(C)[C@H]3CC[C@]4(C)[C@@H](O)[C@H](Cc5cccc(F)c5)C[C@H]4[C@@H]3CC[C@@H]12',
#   '1'],
#  ['CC(C)c1cc(C#N)cc2nc(-c3ccc(C(=O)NCC4CN(c5ccc(-c6ccccc6C(N)=O)cn5)C(=O)O4)cc3)oc12',
#   '0'],
#  ['Cc1cc(C2(c3cccc(-c4cncnc4)c3)N=C(N)c3c(F)cccc32)cn(C)c1=O', '0'],
#  ['NC(=O)c1cncc(C(C(N)=O)c2ccc(F)c(-c3ncnc4cc(N5CCOCC5)ccc34)c2)n1', '0'],
#  ['COc1ccc2ncc(=O)n(CCN3CC[C@@H](NCc4cc5c(cn4)OCCO5)[C@H](O)C3)c2c1', '0'],
#  ['CCn1c(N2CCNC(=O)C2)nc2c([N+](=O)[O-])c(Br)c(Br)cc21', '1'],
#  ['CC(C)(O)[C@]1(C(=O)NCc2cc(C(F)(F)F)cc(C(F)(F)F)c2)CC[C@@H](N2CCC(c3cc(Cl)ncn3)CC2)C1',
#   '1'],
#  ['Cc1nc2ccccc2n1C1CC2CCC(C1)N2CCC1(c2cccc(F)c2)CCN(C(=O)c2cc(S(N)(=O)=O)ccc2F)CC1',
#   '0'],
#  ['COCC(F)(F)CN1[C@H](c2ccc(NC3CN(CCCF)C3)cc2OC)c2ccc3[nH]ncc3c2C[C@H]1C',
#   '1'],
#  ['CC#CCn1c(N2CCC[C@H](N)C2)c(C#N)c2c1c(=O)n(CC(=O)c1cccc(OC)c1)c(=O)n2C',
#   '1'],
#  ['CCS(=O)(=O)N1CC(CC#N)(n2cc(-c3ccnc4[nH]ccc34)cn2)C1', '0'],
#  ['CC[C@@H](C)[C@H](C(=O)O)N1C[C@H](CN2CCC(c3cc(Cc4ccc(OC)c(OC)c4)nn3CC)CC2)[C@@H](c2cccc(F)c2)C1',
#   '0'],
#  ['CC(C)N(C)[C@@H]1CC[C@H](NC(=O)CNC(=O)c2cccc(C(F)(F)F)c2)[C@H](COc2ccccc2)C1',
#   '1'],
#  ['CC[C@H]1CN2CC[C@]3(C(=O)Nc4ccccc43)[C@@H]2C[C@@H]1/C(=C\\OC)C(=O)OC', '0'],
#  ['COc1c(N2CC[C@@H](CN)C2)ccc2c(=O)c(C(=O)O)cn(C3CC3)c12', '0'],
#  ['CC(C)(C)COc1ccc2c(c1)[C@]1(COC(N)=N1)c1cc(-c3cccnc3F)ccc1O2', '0'],
#  ['Nc1ccnc(N2CCC(NC(=O)[C@@H]3CCCO3)(c3ccccc3)CC2)c1', '0'],
#  ['O=C1COc2ccc(CNC34CCC(CC5Cn6c(=O)ccc7ncc(F)c5c76)(CC3)OC4)nc2N1', '1'],
#  ['C[C@H](NC(=O)C1(N)CCN(c2ncnc3[nH]ccc23)CC1)c1ccc(Cl)cc1', '1'],
#  ['CC(C)(O)c1ccc(C(Cc2cc[n+]([O-])cc2)c2ccc(OC(F)F)c(OC3CC3)c2)cn1', '0'],
#  ['FCCc1nccn1Cc1cn(-c2ccc(Cl)c(OC(F)F)c2)nn1', '1'],
#  ['NC1=N[C@@]2(CO1)c1cc(-c3cccnc3F)ccc1Oc1ncc(-c3ccnc(F)c3)cc12', '0'],
#  ['Cc1nsc(-c2nnc3n2CCN(C(=O)c2ccc(F)c(F)c2)[C@@H]3C)n1', '0'],
#  ['C[C@@H]1Cc2c([nH]c3ccc(F)cc23)[C@@H](c2c(F)cnc(OCCN(C)CCCF)c2F)N1CC(F)(F)CO',
#   '1'],
#  ['CC[C@H](Nc1nc(N)nc(N)c1C#N)c1nc2cccc(C#CCCCC(=O)N3CCOCC3)c2c(=O)n1-c1ccccc1',
#   '0'],
#  ['COc1ccc(-c2ccc(C(=O)O)cc2C)cc1-c1cnc(N2CC(F)C2)nc1CN1C(=O)O[C@H](c2cc(C(F)(F)F)cc(C(F)(F)F)c2)[C@@H]1C',
#   '1'],
#  ['O=C(Nc1ccc([C@H]2CNCCO2)cc1)c1ccn(-c2ccccc2)n1', '1'],
#  ['C[C@@H]1c2nnc(-c3cccc(O)n3)n2CCN1C(=O)c1ccc(-c2cccs2)cc1', '1'],
#  ['CN(Cc1nc2ccccc2c(=O)[nH]1)Cc1nc(-c2ccccc2)no1', '0'],
#  ['COc1ccc(C(O)c2cc(-c3nc(Cl)nc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)nn1', '0'],
#  ['CNC[C@H](c1ccc(Cl)c(Cl)c1)[C@H](O)c1ccccc1SC', '1'],
#  ['CCn1nc(Cc2ccc(OC(C)C)cc2)cc1C1CCN(C[C@H]2CN([C@@H](C(=O)O)C(C)(C)C)C[C@@H]2c2cccc(F)c2)CC1',
#   '1'],
#  ['CN1N=C(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)CCC1=O', '0'],
#  ['CO[C@@]12CC[C@@]3(C[C@@H]1[C@](C)(O)C(C)(C)C)[C@H]1Cc4ccc(O)c5c4[C@@]3(CCN1CC1CC1)[C@H]2O5',
#   '1'],
#  ['C[C@@H]1Cc2c([nH]c3ccccc23)[C@@H](c2cncc(OCCNCCCF)c2)N1CC(F)(F)F', '1'],
#  ['CS(=O)(=O)N[C@H]1CC[C@@H](N2CC(NC(=O)CNc3n[nH]c4ccc(C(F)(F)F)cc34)C2)CC1',
#   '0'],
#  ['COc1cccc([C@]2(O)CC[C@H](N3CC(NC(=O)CNc4ncnc5ccc(C(F)(F)F)cc45)C3)CC2)n1',
#   '1'],
#  ['CC[C@](O)(c1cn(Cc2ccc3c(-c4ccccc4)c(C(N)=O)sc3c2)nn1)C(F)(F)F', '0'],
#  ['CCNC(=O)N1C[C@H]2[C@H](C)[C@@H](C)[C@H](/C=C/c3ccc(-c4ccccc4C#N)cn3)[C@@H]3[C@@H](C)OC(=O)[C@@]32C1',
#   '1'],
#  ['Cc1cc(-n2cc(Cn3ccnc3C)nn2)ccc1F', '1'],
#  ['Cc1ncccc1N1C[C@]2(CC[C@@H](c3nc4ccc(OC(F)(F)F)cc4[nH]3)CC2)OC1=O', '0'],
#  ['COc1ccc2ncc(F)c([C@H](O)CN3CCC(NCc4cc5c(cn4)OCCO5)CC3)c2n1', '0'],
#  ['O=S1(=O)CCNCC12CCN(c1cc(F)c(F)cc1Oc1cccc(F)c1)CC2', '1'],
#  ['N#Cc1ccc(Cn2cncc2CN[C@H]2CCN(C(=O)c3cccnc3N)C2=O)cc1', '0'],
#  ['COc1ccc(Cn2ccc3nc(N)nc(NCc4cc(C)on4)c32)nc1OC', '1'],
#  ['FC1(F)CC1Cc1nnc2c(Cl)c(-c3ccc4c(c3)CCO4)ccn12', '1'],
#  ['O=C(CNc1ncnc2ccc(C(F)(F)F)cc12)NC1CN([C@H]2CC[C@@H](c3ccccc3)CC2)C1', '1'],
#  ['CN(c1cccnc1)c1ncccc1CC(c1cccnc1)c1cccnc1', '0'],
#  ['CC[C@@H](NC(=O)c1ccc(Cl)c(F)c1)[C@H]1[C@@H]2C[C@@H](n3cnc4cc(F)c(F)cc43)C[C@@H]21',
#   '1'],
#  ['CNS(=O)(=O)c1cccc(C(=O)N2CCC(CCN3C4CCC3CC(n3c(C)nc5ccccc53)C4)(c3ccccc3)CC2)c1',
#   '0'],
#  ['NCC1(F)CCN(c2nc(Oc3cccc(F)c3)cc(C(F)(F)F)n2)CC1', '1'],
#  ['Cc1cc(C#N)ccc1-c1ccnc(NCc2n[nH]c3nc(F)ccc23)c1', '1'],
#  ['Cc1c(CNC2CCCC2)nn(-c2ccc(Cl)cc2Cl)c1-c1cccnc1', '1'],
#  ['O=C(NC1CCc2cc(CCN3CCN(c4nsc5ccccc45)CC3)ccc21)c1cccnc1', '1'],
#  ['C[C@@H]1Cc2c([nH]c3c(F)cccc23)[C@@H](c2c(F)ccc(OCCNCCCF)c2F)N1CC(F)(F)CO',
#   '1'],
#  ['COc1ccc2ncc(Cl)c(CCN3CCC(NCc4cc5c(cn4)OCCO5)CC3)c2n1', '1'],
#  ['Cc1c([C@@H]2CN3CCN(C(=O)Cc4ccc(-n5cnnn5)nc4)C[C@H]3CS2)ccc2c1COC2=O', '1'],
#  ['Nc1ccnc(N2CCC(NC(=O)c3ccccn3)(c3ccccc3)CC2)c1', '1'],
#  ['COc1ccc2ncc(C#N)c(CCN3CCC(NCc4cc5c(cn4)OCCO5)CC3)c2n1', '1'],
#  ['CCCCc1nccn1Cc1cn(-c2ccc(F)c(C(F)F)c2)nn1', '1'],
#  ['COc1cc(CC[C@@H](C)N2Cc3ccc(Cl)cc3C2)ccc1O', '1'],
#  ['Cn1c(C(C(N)=O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)cccc1=O', '0'],
#  ['CN(C(=O)c1ccc2c(c1)c1c(n2C)CC[C@@H](C2CCOCC2)C1)[C@H](CO)CCC(=O)NCCF', '0'],
#  ['COC(=O)[C@H]1C[C@@H]1COc1ccc2ncc(F)c(CCC34CCC(NCc5ccc6c(n5)NC(=O)CO6)(CC3)CO4)c2n1',
#   '1'],
#  ['NCC(Cc1ccccc1F)c1ccc2ccccc2c1', '1'],
#  ['CC(Oc1ccc(S(C)(=O)=O)cc1C(=O)N1CCN(c2ccc(C(F)(F)F)cc2F)CC1)C(F)(F)F', '1'],
#  ['CNCc1cnc(C)cc1Oc1ccccc1Oc1ccccc1', '1'],
#  ['O=C(Nc1ccc([C@H]2CNCCO2)cc1)c1ccnc(Cl)c1', '0'],
#  ['COCCONC(=O)N(Cc1ccsc1)C1CCN([C@H](C)CCNC(=O)c2c(C)cc(Cl)nc2C)CC1', '0'],
#  ['CC[C@H](C)[C@H](C(=O)O)N1C[C@H](CN2CCC(c3cc(Cc4ccc(OC)c(OC)c4)nn3CC)CC2)[C@@H](c2cccc(F)c2)C1',
#   '0'],
#  ['Cc1nccnc1/C(C(=O)O)=C1/C=CC(=O)C(c2ncnc3cc(N4CCOCC4)ccc23)=C1', '0'],
#  ['Nc1nccn1CC(O)c1cccc(Cl)c1Cl', '1'],
#  ['COCCN1CC=CC[C@H](c2ccc(Cl)c(Cl)c2)C1', '1'],
#  ['Fc1ncccc1-c1cc2sc(N3CCC(N4CCCCC4)CC3)nc2cn1', '1'],
#  ['Cc1c(C(=O)NN2CCCCC2)nn(-c2ccc(Cl)cc2Cl)c1-c1ccc(Cl)cc1', '1'],
#  ['C[C@@H](c1ccc(C(=O)NCCC(=O)O)cc1)n1nc(-c2cc(Cl)cc(Cl)c2)cc1-c1ccc2cc(C(F)(F)F)ccc2c1',
#   '1'],
#  ['CC1CCN([C@H]2CC[C@](NC(=O)C(C)c3cc(C(F)(F)F)cc(C(F)(F)F)c3)(c3ccccc3)CC2)CC1',
#   '1'],
#  ['Cc1nc(N2CCC(O)(C3CC3)CC2)nc2ccc(NC(=O)/C=C/c3ccc(Cl)cc3)cc12', '1'],
#  ['C[C@@H]1Cc2c([nH]c3cccc(F)c23)[C@@H](c2c(F)ccc(OCCNCCCF)c2F)N1CC(F)(F)CO',
#   '1'],
#  ['CCn1cncc1Cn1cc(-c2ccc(Cl)cc2)cn1', '1'],
#  ['CC(C)(C)COc1ccc2c(c1)[C@]1(COC(N)=N1)c1cc(-c3cncnc3)ccc1O2', '1'],
#  ['CN1C(N)=N[C@](C)(c2cc(NC(=O)c3ccc(F)cn3)ccc2F)CS1(=O)=O', '1'],
#  ['CC(C)[C@H]1CC[C@@H](N2CC(NC(=O)CNc3n[nH]c4ccc(C(F)(F)F)cc34)C2)CC1', '1'],
#  ['CC(c1ccc(N2C[C@@H]3C[C@H]2CN3C)cc1)c1ccc2c(c1)Nc1ccccc1S2', '1'],
#  ['COc1cc2ncnc(Oc3ccc(CC(=O)Nc4cnn(C(C)C)c4)cc3)c2cc1OC', '0'],
#  ['Cc1nccnc1C(O)c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)ccc1F', '0'],
#  ['Cc1c(N2CC(C)(CN)C2)c(F)cc2c(=O)c(C(=O)O)cn(C3CC3)c12', '0'],
#  ['Fc1cccc(OC(CC2CNC2)c2ccc(Cl)c(F)c2)c1', '1'],
#  ['O=C(CNc1ccnc2ccc(C(F)(F)F)cc12)NC1CN([C@H]2CC[C@@](O)(c3cncs3)CC2)C1', '1'],
#  ['COc1ccc([C@]2(c3ccc(F)cc3)N=C(c3cc(C#N)ccn3)N[C@H]2C)cn1', '1'],
#  ['CNCC(Cc1ccccc1F)c1ccc2ccccc2c1', '1'],
#  ['CCn1c(N2CCNCC2)nc2c([N+](=O)[O-])c(Br)c(Br)cc21', '1'],
#  ['Fc1ccc(-n2cc(NCCN3CCCCC3)nn2)cc1F', '1'],
#  ['CN(C)CCN1CCN(c2ncc3cc(-c4ccccc4)c(-c4ccc(CN5CCC(c6nnc(-c7ccccn7)[nH]6)CC5)cc4)nc3n2)CC1',
#   '1'],
#  ['Cc1ccc(Oc2ccc(Cl)c(Cl)c2)c(CN(C)C)c1', '1'],
#  ['c1ccc(CCCNCCN(c2ccccc2)c2ccccc2)cc1', '1'],
#  ['OC(c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1)c1ncccc1OC(F)F', '0'],
#  ['COc1ccc(C(C)NC(=O)C2(N)CCN(c3ncnc4[nH]ccc34)CC2)cc1OC', '0'],
#  ['CNC(=O)c1ccc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)nn1', '0'],
#  ['C[C@H]1OC(=O)[C@]2(CCC(N)=O)CC(F)(F)[C@@H](C)[C@H](/C=C/c3ccc(-c4ccccc4C#N)cn3)[C@H]12',
#   '1'],
#  ['OC1(CN2CCC(F)(F)C2)CCN(c2nc(Oc3cccc(F)c3)cc(C(F)(F)F)n2)CC1', '1'],
#  ['C[C@H]1C[C@H]2CSC(N)=N[C@@]2(c2cc(NC(=O)c3ccc(C#N)cn3)cs2)CO1', '1'],
#  ['OCCc1nccn1Cc1cn(-c2ccc(S(F)(F)(F)(F)F)cc2)nn1', '1'],
#  ['CN1CCN(Cc2ccc3c(c2)Cc2c-3n[nH]c2-c2csc(C#CCOc3cccc(Cl)c3)c2)CC1', '1'],
#  ['C[C@@H]1Cc2c([nH]c3ccccc23)[C@@H](c2cc(OCCNCCCF)ccn2)N1CC(F)(F)F', '1'],
#  ['Cc1cccc([C@H]2CC[C@@H](CNC(=O)c3ccc(-c4nc5cc(C#N)cc(C(C)C)c5o4)cc3)CC2)c1',
#   '1'],
#  ['O=C(CNC(=O)c1cccc(C(F)(F)F)c1)NC1CN([C@H]2CC[C@@](O)(c3cncs3)CC2)C1', '0'],
#  ['O=C(NCC(=O)N1CC[C@H](N[C@H]2CC[C@@](O)(c3ccc(-c4nccs4)cn3)CC2)C1)c1cccc(C(F)(F)F)c1',
#   '0'],
#  ['Cc1ncc(-c2ccnc(Nc3ccc(C(=O)N(C)C)c(F)c3)n2)n1C(C)C', '1'],
#  ['CN1CCN(Cc2ccc3c(c2)Cc2c-3n[nH]c2-c2csc(C#CCNC(=O)Oc3ccccc3)c2)CC1', '1'],
#  ['CC(=O)c1cccc(-c2ccc([C@H]3COC[C@H]3NS(=O)(=O)C(C)C)cc2)c1', '0'],
#  ['O=P(Nc1cc(F)ccc1-n1cccn1)(c1ccccc1)c1ccccc1', '0'],
#  ['Nc1nc(NCc2cc(C3CC3)on2)c2c(ccn2Cc2ccccn2)n1', '1'],
#  ['CC1(C)C[C@@H](NC(=O)c2cccc3[nH]ncc23)c2cc(-c3ccc(Cl)cc3)c(-c3ccc(Cl)cc3Cl)nc2O1',
#   '0'],
#  ['O=C(O)[C@@H](CO)NCc1cc(Cl)c(OCc2cccc(-c3ccccc3)c2Br)cc1OCc1ccc2nonc2c1',
#   '0'],
#  ['CC(O)(c1ccccc1)c1ccc(C(Cc2cc[n+]([O-])cc2)c2ccc(OC(F)F)c(OC(F)F)c2)cn1',
#   '1'],
#  ['CCc1cc(Cn2cc(-c3ccc(F)c(C(F)F)c3)cn2)n[nH]1', '1'],
#  ['OC(c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1)c1ccc(OC(F)F)nn1', '0'],
#  ['O=S(=O)(NCC1CC2(c3ccc(F)cc3)NC1CCC2NCc1cc(OC(F)(F)F)ccc1OC1CC1)c1ccccc1',
#   '1'],
#  ['CC(C)S(=O)(=O)N[C@H]1CN(C)C[C@@H]1c1ccc(-c2cccnc2)cc1', '0'],
#  ['COc1cncnc1C(O)c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)ccc1Cl', '0'],
#  ['COc1ccc(-c2ccc(C(=O)O)cc2C)cc1-c1cnc(N(C)C)nc1CN1C(=O)O[C@H](c2cc(F)cc(C(F)(F)F)c2)[C@@H]1C',
#   '0'],
#  ['CNCc1cc(C(N)=O)ccc1Oc1ccc(Cl)cc1C', '1'],
#  ['COc1cccc(C2CCN([C@@H]3CC[C@@](C(=O)NCc4cc(C(F)(F)F)cc(C(F)(F)F)c4)(C(C)C)C3)CC2)c1',
#   '1'],
#  ['COc1cnccc1[C@H]1CC[C@H](N2CC(NC(=O)CNC(=O)c3cccc(C(F)(F)F)c3)C2)CC1', '1'],
#  ['CN(C(=O)N1CC(c2cc(F)ccc2F)=C[C@@]1(CO)c1ccccc1)C1CCNCC1', '1'],
#  ['O=C1COc2ccc(CNC34CCC(CCc5c(F)cnc6ccc(OCC7(O)COC7)nc56)(CC3)OC4)nc2N1', '1'],
#  ['CNC[C@H](c1ccc2ccccc2c1)[C@H](OCC(=O)N1CCCC1)c1ccccc1', '1'],
#  ['CN(C)Cc1ccc2c(c1)CC[C@H](N(C)C(=O)c1ccc(-c3ccc(F)cc3)nc1)C2', '1'],
#  ['Cc1ccc2[nH]c3c(c2c1)C[C@@H](C)N(CC(F)(F)CO)[C@@H]3c1c(F)ccc(OCCNCCCF)c1F',
#   '1'],
#  ['COc1ccc2nccc([C@@H](O)CC[C@@H]3CCN(C4CC(c5c(F)cccc5F)C4)C[C@@H]3C(=O)O)c2c1',
#   '0'],
#  ['CN(C)C(=O)[C@@H](c1ccc(C2=CN3N=CNC3C=C2)cc1)[C@H](N)C(=O)N1CC[C@H](F)C1',
#   '0'],
#  ['C[C@H](CCc1ccc(OC(=O)N(C)C)c(OC(F)(F)F)c1)N1Cc2ccc(F)cc2C1', '1'],
#  ['c1ccc(Nc2nc3c(s2)CCc2[nH]ncc2-3)nc1', '1'],
#  ['CN1CCN(Cc2ccc3c(c2)Cc2c-3n[nH]c2-c2csc(C#CCOc3cccnc3)c2)CC1', '1'],
#  ['O=C(N[C@H]1CC[C@H](C(=O)O)CC1)[C@H](C1CCCCC1)n1c(-c2ccc(Cl)cc2)nc2cc(F)c(F)cc21',
#   '1'],
#  ['CC(C)Oc1cc(-n2cnc3cnc(N[C@@H](C)c4ncc(F)cn4)nc32)n[nH]1', '0'],
#  ['COc1ccc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)sc34)c(F)cc2Cl)nn1', '0'],
#  ['Cc1ccnc(C)c1C(=O)N1CCC(C)(N2CCC(N(c3ccccc3)c3ccccc3)CC2)CC1', '1'],
#  ['CC(O)(c1cccc(-c2ncnc3cc(N4CCOCC4)ccc23)c1)c1nccs1', '0'],
#  ['Clc1cnc2oc(N3CCN4CCC3CC4)nc2c1', '1'],
#  ['COc1ccc(C(=O)NC2(c3ccccc3)CCN(c3cc(N)ccn3)CC2)c(OC)c1', '1'],
#  ['COC(=O)c1ccc(-c2ccn3c(CC4CC4(F)F)nnc3c2Cl)c(F)c1', '1'],
#  ['C[C@H]1C[C@@H](N2C(=N)N[C@](C)(c3cccc(Nc4ccc(C5CC5)nc4)c3Cl)CC2=O)CCO1',
#   '1'],
#  ['CNc1cc(F)cc2c1[nH]c1nc(Oc3cnc(C)nc3)nc(N3CC(=CC(C)N)C3)c12', '0'],
#  ['O=C(O)C1CC2(c3ccc(F)cc3)NC1CCC2NCc1cc(OC(F)(F)F)ccc1OC1CC1', '1'],
#  ['NC1=NC2(CO1)c1cc(-c3cncc(OC(F)F)c3)ccc1OCC21CC1', '1'],
#  ['CC(C)(CCc1ccc(O)c(OC(F)(F)F)c1)N1Cc2cccc(F)c2C1', '1'],
#  ['CC(C)(N)C(=O)N1CCn2c(nc(-c3ccc(F)cc3)c2Nc2ccc(Cl)cc2)C1', '1'],
#  ['N#Cc1c(-c2ccccc2)cc(-c2ccccc2)nc1/N=C1\\SCC(=O)N1c1ccccc1', '0'],
#  ['C[C@H](CCc1ccc(O)c(OC(C)(C)C)c1)N1Cc2cccc(F)c2C1', '0'],
#  ['CO[C@@]1(CC23CCC(NCc4ccc5c(n4)NC(=O)CO5)(CC2)CO3)Cn2c(=O)ccc3ncc(F)c1c32',
#   '1'],
#  ['CCn1nc(Cc2ccc(C#N)cc2)cc1C1CCN(C[C@H]2CN([C@@H](C(=O)O)C(C)(C)C)C[C@@H]2c2cccc(F)c2)CC1',
#   '1'],
#  ['Cc1nnc(-c2c(N)ncnc2N[C@@H](C)c2nc3cccc(C#CCO)c3c(=O)n2-c2ccccc2)o1', '1'],
#  ['Cc1ncc([C@]2(O)CC[C@H](N3CC(NC(=O)CNc4ncnc5ccc(C(F)(F)F)cc45)C3)CC2)s1',
#   '0'],
#  ['Clc1ccc(Cn2cc(NCCN3CCCCC3)nn2)cc1Cl', '1'],
#  ['C[C@@H]1Cc2c(ccc3[nH]ncc23)[C@@H](c2ccc(NC3CN(CCCF)C3)cn2)N1CC(C)(F)F',
#   '0'],
#  ['Nc1nc2c(C(=O)N[C@@H]3CN4CCC3CC4)cc(Cl)cc2o1', '1'],
#  ['OCCOc1ccc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)nn1', '0'],
#  ['CC#CC(CC(=O)O)c1ccc(Oc2ccc(C(F)(F)F)cc2OC(F)F)cc1', '0'],
#  ['CS(=O)(=O)C1(c2cc(N3CCOCC3)nc(-c3cccc4[nH]ccc34)n2)CCNCC1', '0'],
#  ['CN1C(=O)C=C[C@]2(C)[C@H]3CC[C@]4(C)[C@@H](O)/C(=C/c5cccc(F)c5)C[C@H]4[C@@H]3CC[C@@H]12',
#   '1'],
#  ['C[C@@H]1Cc2c([nH]c3ccccc23)[C@@H](c2cccc(OCCNCCCF)c2F)N1CC(F)(F)F', '1'],
#  ['Cc1cc(N)c(S(N)(=O)=O)cc1C(=O)Nc1cc(F)c(F)c(F)c1', '0'],
#  ['FC(F)c1cc(-n2cc(Cn3ccnc3C3CC3)nn2)ccc1Cl', '1'],
#  ['C[C@@H](CN1[C@H](c2c(F)ccc(OCCNCCCF)c2Cl)c2[nH]c3ccccc3c2C[C@H]1C(F)F)C(=O)O',
#   '0'],
#  ['CNC[C@H](c1ccc2ccccc2c1)[C@H](OCCO)c1ccccc1', '1'],
#  ['CNC(=O)C(c1cc(-c2ncnc3cc(N4CCOCC4)ccc23)c(F)cc1Cl)c1nccnc1OC', '0'],
#  ['CC(C)CNc1nc(C#N)nc(N2CCNCC2)c1N', '0'],
#  ['c1ccc([C@H]([C@@H](c2ccccc2)N2CCCC2)N2CCCC2)cc1', '0'],
#  ['Nc1ccnc(N2CCC(C(=O)Nc3ccc4ccccc4n3)(c3ccccc3)CC2)c1', '1'],
#  ['COc1cc(F)ccc1-n1cc(Cn2ccnc2C2CC2)nn1', '1'],
#  ['N#Cc1ccc2ccc(=O)n(CCN3CCC(NCc4cc5c(cn4)OCCO5)CC3)c2c1', '0'],
#  ['Cc1cc(-c2ccc3c(c2)CC[C@H]3N2CC3(CCN(C(=O)Cc4cn5cc(C)sc5n4)CC3)C2)ncn1',
#   '1'],
#  ['CCC(C)(C)c1ccc(S(=O)(=O)Nc2ccc([C@]34CNC[C@H]3C4)cc2)cc1', '1'],
#  ['C[C@@H]1NC(c2cc(C#N)ccn2)=NC1(c1ccc(F)cc1)c1ccc(F)cc1', '1'],
#  ['COCCOc1ccc2ncc(F)c(CCC34CCC(NCc5ccc6c(n5)NC(=O)CO6)(CC3)CO4)c2n1', '1'],
#  ['Nc1nc2cc3c(cc2s1)CCN(Cc1cnc[nH]1)CC3', '0'],
#  ['Cc1nccn1Cc1cn(-c2ccc(F)c(C(F)F)c2)nn1', '1'],
#  ['NCC(=O)N1CCn2c(nc(-c3ccccc3)c2Nc2ccc3c(c2)OCO3)C1', '1'],
#  ['C[C@H]1C[C@H]2CSC(N)=N[C@@]2(c2cc(NC(=O)c3ccc(Cl)cn3)ccc2F)CO1', '1'],
#  ['O=C(N1CCc2ncc(C(F)(F)F)cc2C1)[C@@]12CCC[C@@H]1C[C@@H](NC1CCCC1)C2', '0'],
#  ['C[C@H]1CN(C[C@H](Cc2ccccc2)C(=O)NCC(=O)O)CC[C@@]1(C)c1cccc(O)c1', '0'],
#  ['CCn1cncc1Cn1cc(-c2ccc(F)c(C)c2)cn1', '1'],
#  ['COc1ccc(OC[C@H](C)NCCCF)cc1[C@@H]1c2[nH]c3ccccc3c2C[C@@H](C)N1CC(F)(F)CO',
#   '1'],
#  ['CCCc1nccn1Cc1cn(-c2ccc(F)c(C(F)F)c2)nn1', '1'],
#  ['CCCc1cc(Cn2cc(-c3ccc(F)c(C(F)F)c3)cn2)n[nH]1', '1'],
#  ['Cc1c2c(n3c1CCCN1CCCC[C@@H]1CNc1cc-3ccc1C(N)=O)CC(C)(C)CC2=O', '1'],
#  ['Fc1ccc(-n2cc(Cn3ccnc3C3CC3)nn2)cc1C(F)F', '1'],
#  ['Cc1cc(=O)n(C[C@H](N)[C@H]2CC[C@H](NCc3ccc4c(n3)NC(=O)CO4)CC2)c2cc(F)ccc12',
#   '0'],
#  ['N[C@H](C(=O)N1CCCC1)[C@H]1CC[C@H](NC(=O)c2cccc3ccccc23)CC1', '0'],
#  ['Nc1nccn1Cc1cn(-c2ccc(Cl)c(OC(F)F)c2)nn1', '1'],
#  ['COC1COCCC1N[C@@H]1C[C@H]2CCC[C@@]2(C(=O)N2CCc3ncccc3C2)C1', '0'],
#  ['C[C@@H]1c2nnc(-c3csc(-c4ccc(F)cc4F)n3)n2CCN1C(=O)c1ccc(-c2cccs2)cc1', '1'],
#  ['NC1=N[C@@]2(c3ccc(F)cc3F)CO[C@@H](c3ncco3)C[C@H]2CS1', '1'],
#  ['Cc1cccc(-c2[nH]c(CNc3ccccc3F)nc2-c2ccc3ncnn3c2)n1', '0'],
#  ['CC(C)c1ncc([C@H]2CC[C@@H](N3CC(NC(=O)CNc4nn(C)c5ccc(C(F)(F)F)cc45)C3)CC2)s1',
#   '1'],
#  ['COc1cccc2c1nc(N)n1nc(CN3CCN(c4cnn(C)c4)C[C@H]3C)nc21', '0'],
#  ['O=C(Cc1ccccc1)NCCN(c1ccccc1)c1ccccc1', '1'],
#  ['Cc1ncc(CN[C@@H]2CCN(CCn3c(=O)ccc4ccc(C#N)cc43)C[C@@H]2F)cc1C#N', '0'],
#  ['Cc1ccccc1C(OCCN(C)C)c1ccccc1', '1'],
#  ['Cc1nn(C2(CC#N)CN(S(=O)(=O)C(C)C)C2)cc1-c1ncnc2[nH]ccc12', '0'],
#  ['OC1CCN(Cc2csc(-c3cn(CC4CCOCC4)c4c(Cl)cccc34)n2)CC1', '1'],
#  ['OC(c1ccc(F)c(-c2ncnc3cc(N4CCOCC4)ccc23)c1)c1ncnn2cccc12', '1'],
#  ['Cn1nc(NCC(=O)NC2CN([C@H]3CC[C@@H](C#N)CC3)C2)c2cc(C(F)(F)F)ccc21', '0'],
#  ['Cc1nnc(C(C)C)n1C1CC2CCC(C1)N2CC[C@H](NC(=O)C1CCC(F)(F)CC1)c1ccccc1', '1'],
#  ['Fc1cc(-n2cc(Cn3ccnc3C3CC3)nn2)ccc1Cl', '1'],
#  ['CCC(NC(=O)c1ccc(Cl)cc1)[C@H]1[C@@H]2C[C@@H](n3cnc4cccc(F)c43)C[C@@H]21',
#   '1'],
#  ['CNC[C@H](c1ccc2ccccc2c1)[C@H](O)c1cncc(OC)c1', '0'],
#  ['COc1cnc(NCCNCCCF)cc1[C@@H]1c2[nH]c3ccccc3c2C[C@@H](C)N1CC(F)(F)F', '1'],
#  ['C[C@@]1(c2cc(NC(=O)c3ccc(C#N)cn3)ccc2F)Cn2cc(C#N)nc2C(N)=N1', '1'],
#  ['CNC[C@@H](O)CCN1c2ccccc2N(c2cc(F)ccc2F)S1(=O)=O', '1'],
#  ['Cc1cc(-c2cnn(Cc3ccn(C)n3)c2)ccc1F', '1'],
#  ['OCc1csc(C(O)c2cc(-c3ncnc4cc(N5CCOCC5)ccc34)c(F)cc2Cl)n1', '1'],
#  ['CN(C)C(=O)N1CC(c2cc(F)ccc2F)=C[C@@]1(CC[C@@H](N)C(F)F)c1ccccc1', '1'],
#  ['CNC[C@H](c1ccc(Cl)c(Cl)c1)[C@@H](O)c1ccccc1', '0'],
#  ['O=C(NOCCO)c1ncc2cncn2c1Nc1ccc(I)cc1F', '1'],
#  ['C[C@@]1(c2cc(CNCC(F)(F)F)c(F)cc2F)CCSC(N)=N1', '1'],
#  ['COc1ccc2c(c1)N(CCN1CCC(NCc3ccc4c(n3)NC(=O)CO4)CC1)C(=O)OC2', '0'],
#  ['COCC(=O)O[C@]1(CCN(C)CCCc2nc3ccccc3[nH]2)CCc2cc(F)ccc2[C@@H]1C(C)C', '1'],
#  ['O=C(N[C@H](C1CC1)[C@H]1[C@@H]2C[C@@H](n3cnc4cc(F)c(F)cc43)C[C@@H]21)c1ccc(Cl)cc1',
#   '1'],
#  ['O=c1ccc2ncc(F)c3c2n1CC3C[C@H]1OC[C@H](NCc2cc3c(cn2)OCCC3)CO1', '0'],
#  ['O=c1n(C[C@@H](O)CO)c2ccccc2n1C1CCN(C[C@H]2[C@H]3CC[C@H](C3)C23CC3)CC1',
#   '0'],
#  ['CNCCOc1ccc(Nc2ncc3c(=O)n(-c4c(Cl)cccc4Cl)ccc3n2)cc1', '1'],
#  ['CCOC(=O)C1=C(C)N=C(C)C(C(=O)OC)C1c1cccc([N+](=O)[O-])c1', '1'],
#  ...]

# %%
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.tokenizer import GPT4Tokenizer
tokenizer = GPT4Tokenizer()
tokenizer.load_vocab('vocab.json')
tokenizer.vocab[512] = '<none>'

# %%
print(tokenizer.encode("NC(=O)c1ccc(Cl)cc1)[C@H]1[C@@H]2C[C@@H](n3cnc4cccc(F)c43)C[C@@H]21CNC[C@H](c1ccc2ccccc2c1)[C@H](O)c1cncc(OC)c1COc1cnc(NCCNCCCF)cc1[C@@H]1c2[nH]c3ccccc3c2C[C@@H](C)N1CC(F)(F)FC[C@@]1(c2cc(NC(=O)c3ccc(C#N)cn3)ccc2F)Cn2cc(C#N)n"))
# Out:
# [375, 269, 335, 324, 487, 438, 347, 413, 386, 256, 270, 288, 356, 488, 272, 289, 278, 352, 360, 325, 278, 302, 338, 256, 412, 41, 308, 79, 338, 313, 257, 78, 390, 498, 407, 485, 358, 400, 408, 457, 371, 336, 49, 385, 397, 284, 280, 454, 273, 361, 439, 67, 420, 259, 344, 296]

# %%
encoded_data = []
for row in train_data:
    text = row[0]  # SMILES string
    label = int(row[1])  # Label
    tokens = tokenizer.encode(text)
    encoded_data.append((torch.tensor(tokens), label))

# %%
# pad all sequences to the same length
padded_data = []
for tokens, label in encoded_data:
    padded_tokens = F.pad(tokens, (0, 64 - len(tokens)), value=512)
    padded_data.append((padded_tokens, torch.tensor(label)))

# %%
class ClassificationTransformer(nn.Module):
    def __init__(self, vocab_size, emb_dim=128, num_heads=8, num_layers=6, max_len=64, num_classes=2, dropout=0.1):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, emb_dim, padding_idx=0)
        self.pos_embedding = nn.Embedding(max_len, emb_dim)
        
        encoder_layers = nn.TransformerEncoderLayer(d_model=emb_dim, nhead=num_heads, dropout=dropout)
        self.transformer = nn.TransformerEncoder(encoder_layers, num_layers=num_layers)
        
        self.cls_token = nn.Parameter(torch.randn(1, 1, emb_dim))
        self.fc = nn.Linear(emb_dim, num_classes)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        batch_size, seq_length = x.size()
        cls_tokens = self.cls_token.expand(batch_size, -1, -1)
        x = self.embedding(x) + self.pos_embedding(torch.arange(seq_length, device=x.device).unsqueeze(0))
        x = torch.cat((cls_tokens, x), dim=1)
        x = x.permute(1, 0, 2)  # Transformer expects (seq_length, batch_size, emb_dim)
        x = self.transformer(x)
        x = x[0]  # CLS token
        x = self.dropout(x)
        logits = self.fc(x)
        return logits

class TokenDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data  # List of token tensors
        self.labels = labels  # List of labels
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

def get_batches(dataset, batch_size):
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
    for batch in loader:
        tokens, labels = batch
        yield tokens.to(device), labels.to(device)

def train_model(model, train_dataset, val_dataset, epochs=10, batch_size=32, lr=1e-3):
    optimizer = optim.AdamW(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size)
    
    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for tokens, labels in train_loader:
            tokens, labels = tokens.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(tokens)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        
        avg_loss = total_loss / len(train_loader)
        val_accuracy = evaluate(model, val_loader)
        print(f'Epoch {epoch+1}, Loss: {avg_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')
    
    torch.save(model.state_dict(), 'classification_transformer.pth')

def evaluate(model, loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for tokens, labels in loader:
            tokens, labels = tokens.to(device), labels.to(device)
            outputs = model(tokens)
            _, preds = torch.max(outputs, dim=1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)
    return correct / total

# Example usage
if __name__ == "__main__":
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    vocab_size = 513
    tokens = [item[0] for item in padded_data]
    labels = [item[1] for item in padded_data]
    
    dataset = TokenDataset(tokens, labels)
    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])
    
    model = ClassificationTransformer(vocab_size=vocab_size, max_len=64).to(device)
    train_model(model, train_dataset, val_dataset, epochs=10, batch_size=32, lr=1e-3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 87
#      82 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#      84 vocab_size = 513
# ---> 87 dataset = TokenDataset(padded_data[:, 0], padded_data[:, 1])
#      88 train_size = int(0.8 * len(dataset))
#      89 val_size = len(dataset) - train_size
#
# TypeError: list indices must be integers or slices, not tuple
